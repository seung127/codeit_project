# %% [markdown]
# # DA05 고급프로젝트 1팀 김연우

# %% [markdown]
# # 파일 불러오기

# %% [markdown]
# ### votes 파일

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd
import seaborn as sns



# 폰트 경로를 직접 지정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)

import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rc('font', family='NanumGothicCoding')  # 나눔 고딕으로 설정
mpl.rcParams['axes.unicode_minus'] = False  # 마이너스 깨짐 방지

# %%
import pandas as pd

# GCS 파일 경로
gcs_path = "gs://hq-project/votes/accounts_timelinereport.parquet"
# 예시: gs://codeit-project/hackle/hackle_events.parquet

# GCP 키 경로
key_path = "config/key.json"

# 데이터 불러오기
df = pd.read_parquet(gcs_path, storage_options={"token": key_path})
# path_timelinereport = "gs://hq-project/votes/accounts_timelinereport.parquet"
# 확인
df.head()
# Out:
#    id             reason          created_at  reported_user_id  user_id  \
# 0  28            타인을 사칭함 2023-05-06 04:44:57            874587   885082
# 1  37  친구를 비하하거나 조롱하는 어투 2023-05-06 05:41:19            881048   881298
# 2  46  친구를 비하하거나 조롱하는 어투 2023-05-06 06:26:59            887882   881945
# 3  64           허위 사실 언급 2023-05-06 07:07:46            888610   893684
# 4  65           허위 사실 언급 2023-05-06 07:07:52            888610   893684
#
#    user_question_record_id
# 0                  3920588
# 1                  4018679
# 2                  4120914
# 3                  4143049
# 4                  4143049

# %%
! pip install koreanize_matplotlib
import koreanize_matplotlib
# !pip install seaborn

# %%
# 파일 경로 지정 (votes)
path_timelinereport = "gs://hq-project/votes/accounts_timelinereport.parquet"
path_friendrequest = "gs://hq-project/votes/accounts_friendrequest.parquet"
path_attendance    = "gs://hq-project/votes/accounts_attendance.parquet"
path_blockrecord    = "gs://hq-project/votes/accounts_blockrecord.parquet"        
path_failpaymenthistory = "gs://hq-project/votes/accounts_failpaymenthistory.parquet"
path_group = "gs://hq-project/votes/accounts_group.parquet"
path_nearbyschool = "gs://hq-project/votes/accounts_nearbyschool.parquet"
path_paymenthistory = "gs://hq-project/votes/accounts_paymenthistory.parquet"
path_pointhistory = "gs://hq-project/votes/accounts_pointhistory.parquet"
path_school = "gs://hq-project/votes/accounts_school.parquet"
path_user = "gs://hq-project/votes/accounts_user.parquet"
path_user_contacts = "gs://hq-project/votes/accounts_user_contacts.parquet"
path_userquestionrecord = "gs://hq-project/votes/accounts_userquestionrecord.parquet"
path_userwithdraw  = "gs://hq-project/votes/accounts_userwithdraw.parquet"
path_receipts = "gs://hq-project/votes/event_receipts.parquet"
path_event = "gs://hq-project/votes/events.parquet"
path_question = "gs://hq-project/votes/polls_question.parquet"
path_questionpiece  = "gs://hq-project/votes/polls_questionpiece.parquet"
path_questionreport = "gs://hq-project/votes/polls_questionreport.parquet"
path_questionset = "gs://hq-project/votes/polls_questionset.parquet"
path_usercandidate = "gs://hq-project/votes/polls_usercandidate.parquet"


# 파일 불러오기 (votes)
timelinereport = pd.read_parquet(path_timelinereport, storage_options={"token": None})
friendrequest = pd.read_parquet(path_friendrequest, storage_options={"token": None})
attendance = pd.read_parquet(path_attendance, storage_options={"token": None})
blockrecord = pd.read_parquet(path_blockrecord, storage_options={"token": None})
failpaymenthistory = pd.read_parquet(path_failpaymenthistory, storage_options={"token": None})
group = pd.read_parquet(path_group, storage_options={"token": None})
nearbyschool = pd.read_parquet(path_nearbyschool, storage_options={"token": None})
paymenthistory = pd.read_parquet(path_paymenthistory, storage_options={"token": None})
pointhistory = pd.read_parquet(path_pointhistory, storage_options={"token": None})
school = pd.read_parquet(path_school, storage_options={"token": None})
user = pd.read_parquet(path_user, storage_options={"token": None})
user_contacts = pd.read_parquet(path_user_contacts, storage_options={"token": None})
userquestionrecord = pd.read_parquet(path_userquestionrecord, storage_options={"token": None})
userwithdraw = pd.read_parquet(path_userwithdraw, storage_options={"token": None})
receipts = pd.read_parquet(path_receipts, storage_options={"token": None})
event = pd.read_parquet(path_event, storage_options={"token": None})
question = pd.read_parquet(path_question, storage_options={"token": None})
questionpiece = pd.read_parquet(path_questionpiece, storage_options={"token": None})
questionreport = pd.read_parquet(path_questionreport, storage_options={"token": None})
questionset = pd.read_parquet(path_questionset, storage_options={"token": None})
usercandidate = pd.read_parquet(path_usercandidate, storage_options={"token": None})

# %% [markdown]
# ### hackle 파일

# %%
# 파일 경로 지정 (hackle)
path_device_properties = "gs://hq-project/hackle/device_properties.parquet"
path_hackle_events  = "gs://hq-project/hackle/hackle_events.parquet"    


# 파일 불러오기 (hackle)
device_properties = pd.read_parquet(path_device_properties, storage_options={"token": None})
hackle_events = pd.read_parquet(path_hackle_events, storage_options={"token": None})

# %%
# 파일 경로 지정 (hackle)
path_hackle_properties = "gs://hq-project/hackle/hackle_properties.parquet"
path_user_properties = "gs://hq-project/hackle/user_properties.parquet"
# 파일 불러오기 (hackle)
hackle_properties = pd.read_parquet(path_hackle_properties, storage_options={"token": None})
user_properties = pd.read_parquet(path_user_properties, storage_options={"token": None})

# %%
# 주소 통일

school['address'] = school['address'].str.replace(
    r'^서울\s', '서울특별시 ', regex=True
)

school['address'] = school['address'].str.replace(
    r'^경기\s', '경기도 ', regex=True
)

school['address'] = school['address'].str.replace(
    r'^강원\s', '강원도 ', regex=True
)
school['address'] = school['address'].str.replace(
    r'^강원도\s', '강원특별자치도 ', regex=True
)

school['address'] = school['address'].str.replace(
    r'^충북\s', '충청북도 ', regex=True
)

school['address'] = school['address'].str.replace(
    r'^충남\s', '충청남도 ', regex=True
)

school['address'] = school['address'].str.replace(
    r'^전북\s', '전북특별자치도 ', regex=True
)

school['address'] = school['address'].str.replace(
    r'^전라북도\s', '전북특별자치도 ', regex=True
)

school['address'] = school['address'].str.replace(
    r'^전남\s', '전라남도 ', regex=True
)

school['address'] = school['address'].str.replace(
    r'^경북\s', '경상북도 ', regex=True
)

school['address'] = school['address'].str.replace(
    r'^경남\s', '경상남도 ', regex=True
)

school['address'] = school['address'].str.replace(
    r'^대구\s', '대구광역시 ', regex=True
)

school['address'] = school['address'].str.replace(
    r'^인천\s', '인천광역시 ', regex=True
)

school['address'] = school['address'].str.replace(
    r'^제주\s', '제주특별자치도 ', regex=True
)

school['address'] = school['address'].str.replace(
    r'^대한민국 강원도\s', '강원특별자치도 ', regex=True
)

# %% [markdown]
# ### votes 파일 테이블 설명

# %% [markdown]
# | 번호 | 테이블 명 | 설명
# |---|------------------|------------|
# |1	|attendance	|출석 테이블|
# |2	|blockrecord	|차단 기록 테이블	|
# |3	|failpaymenthistory	|상품 구매 실패 기록 테이블	|
# |4	|friendrequest	|친구 요청 테이블	|
# |5	|group	|학급 테이블	|
# |6	|nearbyschool	|가까운 학교를 기록해두기 위한 관계형 테이블|
# |7	|paymenthistory	|구매 기록 테이블	|
# |8	|user_contacts	|유저 컨택 테이블	|
# |9	|pointhistory	|포인트 기록 테이블	|
# |10	|school	|학교 테이블	|
# |11	|timelinereport	|유저 신고기록 테이블|
# |12	|user	|유저 테이블|
# |13	|userquestionrecord	|투표 기록 테이블	|
# |14	|userwithdraw	|포인트 이벤트 참여 테이블|
# |15	|event_receipts		||
# |16	|events	|포인트 이벤트 테이블|
# |17	|question	|질문 내용 테이블|
# |18	|questionpiece	|질문에 대한 신고 기록 테이블	한 질문 세트는 10개의 질문으로 구성됩니다.|
# |19	|questionreport	|	|
# |20	|questionset	|질문 세트 데이블 	유저가 질문 한 세트에 대한 답변을 끝낼때 생성되는 데이터입니다.|
# |21	|usercandidate	|질문에 등장하는 유저들 테이블	한 질문마다 최대 8명이 등장합니다.|

# %% [markdown]
# ### 1. hackle테이블 명세
#
# | 컬럼명         | 컬럼 설명     | 비고 |
# |----------------|---------------|------|
# | session_id     | 세션 식별자   |      |
# | user_id        | 사용자 ID     |      |
# | language       | 사용 언어     |      |
# | osname         | 운영 체제 이름 |      |
# | osversion      | 운영 체제 버전 |      |
# | versionname    | 앱 버전 이름  |      |
# | device_id      | 장치 ID       |      |
#
# | 컬럼명         | 컬럼 설명   | 비고 |
# |----------------|-------------|------|
# | device_id      | 장치 ID     |      |
# | device_model   | 장치 모델명 |      |
# | device_vendor  | 장치 제조사 |      |
#
# | 컬럼명         | 컬럼 설명             | 비고 |
# |----------------|------------------------|------|
# | event_id       | 고유 이벤트 ID         |      |
# | event_datetime | 이벤트 발생 시간       |      |
# | event_key      | 이벤트 키              |      |
# | session_id     | 세션 ID                |      |
# | item_name      | 이벤트 관련 아이템 이름 |     |
# | page_name      | 이벤트 발생 페이지 이름 |     |
# | friend_count   | 친구 수                |      |
# | votes_count    | 받은 투표 수           |      |
# | heart_balance  | 잔여 하트              |      |
# | question_id    | 고유 질문 ID           |      |
# | 컬럼명   | 컬럼 설명     | 비고 |
# |----------|---------------|------|
# | class    | 사용자 반     |      |
# | gender   | 사용자 성별   |      |
# | grade    | 사용자 학년   |      |
# | school_id| 사용자 학교 ID |     |

# %% [markdown]
# ### hackle 이벤트 목록
#
# | 번호 | 이벤트명                         | 이벤트 설명                                           | 비고       |
# |------|----------------------------------|--------------------------------------------------------|------------|
# | 1    | $session_start                   | 세션 시작                                              |            |
# | 2    | $session_end                     | 세션 종료                                              |            |
# | 3    | button                           | -                                                      | 전처리 대상 |
# | 4    | click_appbar_alarm_center        | 상단 appbar에서 알림 모양 클릭                         |            |
# | 5    | click_appbar_chat_rooms          | 상단 appbar에서 메시지 모양 클릭                       |            |
# | 6    | click_appbar_friend_plus         | 상단 appbar에서 친구 모양 클릭                         |            |
# | 7    | click_appbar_setting             | -                                                      | 전처리 대상 |
# | 8    | click_attendance                 | 출석체크 클릭                                          |            |
# | 9    | click_autoadd_contact            | 친구 추천 탭 위의 연락처 자동 친구 추가하기 버튼 클릭 |            |
# | 10   | click_bottom_navigation_lab      | 하단 네비게이션에서 lab 클릭                           |            |
# | 11   | click_bottom_navigation_profile  | 하단 네비게이션에서 프로필 클릭                        |            |
# | 12   | click_bottom_navigation_questions| 하단 네비게이션에서 질문 클릭                          |            |
# | 13   | click_bottom_navigation_timeline | 하단 네비게이션에서 타임라인 클릭                      |            |
# | 14   | click_community_chat             | 채팅 클릭                                              |            |
# | 15   | click_copy_profile_link_ask      | ask에서 내 프로필 링크 복사하기 클릭                   |            |
# | 16   | click_copy_profile_link_profile  | 본인 프로필 링크 복사하기 클릭                         |            |
# | 17   | click_friend_invite              | 질문 대기상태에서 친구 초대하고 바로 받기 클릭        |            |
# | 18   | click_invite_friend              | ask에서 친구 초대하기 클릭                             |            |
# | 19   | click_notice                     | 알림 센터 클릭                                         |            |
# | 20   | click_notice_detail              | 알림 센터 디테일에서 특정 알림을 클릭                 |            |
# | 21   | click_profile_ask                | 친구 프로필에서 ‘친구에게 글을 남길까?’ 클릭           |            |
# | 22   | click_purchase                   | 구매할 하트 상품 클릭                                  |            |
# | 23   | click_question_ask               | 홈화면에서 ask 클릭                                    |            |
# | 24   | click_question_open              | 받은 질문을 열 때                                      |            |
# | 25   | click_question_share             | 받은 질문을 공유할 때                                  |            |
# | 26   | click_question_start             | 홈화면에서 질문 start 클릭                             |            |
# | 27   | click_random_ask_normal          | 기존 타임라인에서 일반적인 ask 클릭                   |            |
# | 28   | click_random_ask_other           | 기존 타임라인에서 다른 친구에게 글 남기기 클릭        |            |
# | 29   | click_random_ask_shuffle         | 기존 타임라인에서 ask 랜덤 셔플 클릭                  |            |
# | 30   | click_timeline_chat_start        | 기존 타임라인에서 채팅 클릭                           |            |
# | 31   | complete_purchase                | 하트 구입 완료                                         |            |
# | 32   | complete_question                | 질문 완료                                              |            |
# | 33   | complete_signup                  | 회원가입 완료                                          |            |
# | 34   | launch_app                       | 앱 실행                                                |            |
# | 35   | skip_question                    | 질문 스킵                                              |            |
# | 36   | view_friendplus_tap              | 친구 추천 화면 진입                                    |            |
# | 37   | view_home_tap                    | 홈 진입                                                |            |
# | 38   | view_lab_tap                     | 실험실 탭에 진입                                       |            |
# | 39   | view_login                       | 로그인 페이지 진입                                     |            |
# | 40   | view_profile_tap                 | 프로필 화면 진입                                       |            |
# | 41   | view_questions_tap               | 질문 화면 진입                                         |            |
# | 42   | view_shop                        | 하트 충전소 진입                                       |            |
# | 43   | view_signup                      | 회원가입 페이지 진입                                   |            |
# | 44   | view_timeline_tap                | 타임라인 화면 진입                                     |            |

# %% [markdown]
# # 데이터 EDA

# %%
user['id'] = user['id'].astype(str)# 추후 분석을 위한 데이터 타입 변경
questionpiece['id'] = questionpiece['id'].astype(str)
questionset['user_id'] = questionset['user_id'].astype(str)
paymenthistory['user_id'] = paymenthistory['user_id'].astype(str)
pointhistory['user_id'] = pointhistory['user_id'].astype(str)
usercandidate['user_id'] = usercandidate['user_id'].astype(str)
userquestionrecord['user_id'] = userquestionrecord['user_id'].astype(str)
userquestionrecord['chosen_user_id'] = userquestionrecord['chosen_user_id'].astype(str)

# %%
#1 출석 수 계산하기
import pandas as pd
import ast

# attendance_date_list를 문자열에서 리스트로 변환하고 날짜 수 계산
attendance['date_count'] = attendance['attendance_date_list'].apply(lambda x: len(ast.literal_eval(x)))

# id와 date_count만
result = attendance[['id', 'date_count']]

top10_attendance = result.sort_values(by='date_count', ascending=False).head(10).reset_index(drop=True)

top10_attendance
# Out:
#        id  date_count
# 0   39622         310
# 1   30870         302
# 2   22468         277
# 3    8971         274
# 4   11979         273
# 5   25680         270
# 6  250294         269
# 7    7923         267
# 8   18220         264
# 9   22140         262

# %%
question # id값 존재
# Out:
#         id                           question_text          created_at
# 0       99                      가장 신비한 매력이 있는 사람은? 2023-03-31 15:22:53
# 1      100            "이 사람으로 한 번 살아보고 싶다" 하는 사람은? 2023-03-31 15:22:53
# 2      101                               미래의 틱톡커는? 2023-03-31 15:22:54
# 3      102                         여기서 제일 특이한 친구는? 2023-03-31 15:22:54
# 4      103                         가장 지켜주고 싶은 사람은? 2023-03-31 15:22:55
# ...    ...                                     ...                 ...
# 5020  5129                         나에게 가장 중요한 사람은? 2023-06-06 06:15:52
# 5021  5130                    오목을 제일 잘 할 것 같은 사람은? 2023-06-06 06:15:52
# 5022  5131                가방에서 쓰레기가 안 나올 것 같은 사람은? 2023-06-06 06:15:52
# 5023  5132  아무리 많은 숙제도 30분만에 다 끝내버릴 수 있을 것 같은 친구는? 2023-06-06 06:15:52
# 5024  5133                  러브레터를 가장 잘 쓸 것 같은 사람은? 2023-06-06 06:15:52
#
# [5025 rows x 3 columns]

# %%
questionpiece # question_id 존재.
# Out:
#                 id  is_voted          created_at  question_id  is_skipped
# 0           998458         1 2023-04-28 12:27:22          252           0
# 1           998459         1 2023-04-28 12:27:22          244           0
# 2           998460         1 2023-04-28 12:27:22          183           0
# 3           998461         1 2023-04-28 12:27:22          101           0
# 4           998462         1 2023-04-28 12:27:22          209           0
# ...            ...       ...                 ...          ...         ...
# 1265471  208385226         0 2024-05-07 11:32:30          960           0
# 1265472  208385227         0 2024-05-07 11:32:30         1402           0
# 1265473  208385228         0 2024-05-07 11:32:30         1676           0
# 1265474  208385229         0 2024-05-07 11:32:30         3115           0
# 1265475  208385230         0 2024-05-07 11:32:30         1461           0
#
# [1265476 rows x 5 columns]

# %%
questionreport # question_id 존재
# Out:
#           id                reason          created_at  question_id  user_id
# 0          1           이 질문은 재미없어요 2023-04-19 06:20:35          250   837556
# 1          2           이 질문은 재미없어요 2023-04-19 06:58:09          113   837672
# 2          3       불쾌한 내용이 포함되어 있음 2023-04-19 06:58:17          113   837672
# 3          4  어떻게 이런 생각을? 이 질문 최고! 2023-04-19 08:12:42          119   837922
# 4          5  어떻게 이런 생각을? 이 질문 최고! 2023-04-19 08:12:50          119   837922
# ...      ...                   ...                 ...          ...      ...
# 51419  55763                 그냥 싫어 2024-04-19 12:49:57          350  1542237
# 51420  55764                 그냥 싫어 2024-04-19 12:50:02         3541  1542237
# 51421  55765                 그냥 싫어 2024-04-28 06:35:38          392   984791
# 51422  55766                 그냥 싫어 2024-04-30 04:48:25         4979  1583634
# 51423  55767                 그냥 싫어 2024-05-05 14:56:25         3438  1397426
#
# [51424 rows x 5 columns]

# %%
questionset
# Out:
#               id                             question_piece_id_list  \
# 0          99817  [998458, 998459, 998460, 998461, 998462, 99846...
# 1          99830  [998588, 998589, 998590, 998591, 998592, 99859...
# 2          99840  [998689, 998691, 998693, 998695, 998697, 99869...
# 3          99841  [998688, 998690, 998692, 998694, 998696, 99869...
# 4          99848  [998768, 998769, 998770, 998771, 998772, 99877...
# ...          ...                                                ...
# 158379  20838253  [208383291, 208383292, 208383293, 208383294, 2...
# 158380  20838344  [208384201, 208384202, 208384203, 208384204, 2...
# 158381  20838419  [208384951, 208384952, 208384953, 208384954, 2...
# 158382  20838445  [208385211, 208385212, 208385213, 208385214, 2...
# 158383  20838446  [208385221, 208385222, 208385223, 208385224, 2...
#
#               opening_time status          created_at  user_id
# 0      2023-04-28 12:27:22      F 2023-04-28 12:27:23   849436
# ...

# %% [markdown]
# question,questionpiece,questionreport,questionset을 이용해서 얻을 수 있는 인사이트가 무엇이 있을까.
#
# 1. question과 questionpiece를 엮어서 어떤 질문이 투표 받았는 지 스킵 되었는 지 ? 알면 뭐 할까
# 2.

# %%
user
# Out:
#              id  is_superuser  is_staff gender  point  \
# 0        831956             1         1   None    600
# 1        831962             0         0      F   2248
# 2        832151             0         0      M   1519
# 3        832340             0         0      F     57
# 4        832520             0         0      M   1039
# ...         ...           ...       ...    ...    ...
# 677080  1583729             0         0      M    300
# 677081  1583730             0         0      M    420
# 677082  1583731             0         0      M    300
# 677083  1583732             0         0      F    300
# 677084  1583733             0         0      F    300
#
#                                            friend_id_list  is_push_on  \
# 0       [1292473, 913158, 1488461, 1064695, 1043565, 1...           0
# 1       [833025, 832642, 982531, 879496, 838541, 83752...           1
# 2       [838785, 982531, 882567, 879496, 838541, 83649...           0
# ...

# %%
user['is_superuser'].value_counts()
# Out:
# is_superuser
# 0    677083
# 1         2
# Name: count, dtype: int64

# %%
common_ids = set(user['id']) & set(questionreport['user_id'])
len(common_ids)
# Out:
# 0

# %%
# 두 컬럼의 고유값 추출
report_ids = set(questionreport['user_id'].unique())
user_ids = set(user['id'].unique())

# 겹치는 ID 확인
common_ids = report_ids.intersection(user_ids)

# 결과 출력
print(f"겹치는 ID 수: {len(common_ids)}")
# Out:
# 겹치는 ID 수: 0

# %%
pointhistory,receipts,questionreport,questionpiece,receipts,questionset,
# 위 코드에 대입해서 어떤 테이블끼리 id가 겹치는지 확인
# Out:
# (                id  delta_point          created_at user_id  \
#  0           790629            9 2023-04-28 12:27:49  849436
#  1           790652            9 2023-04-28 12:28:02  849436
#  2           790664            5 2023-04-28 12:28:09  849436
#  3           790680           13 2023-04-28 12:28:16  849436
#  4           790703            5 2023-04-28 12:28:26  849436
#  ...            ...          ...                 ...     ...
#  2338913  340672371           14 2024-05-08 01:35:02  855509
#  2338914  340672372           11 2024-05-08 01:36:00  855525
#  2338915  340672373           11 2024-05-08 01:36:00  855526
#  2338916  340672374           12 2024-05-08 01:36:18  855525
#  2338917  340672375           12 2024-05-08 01:36:18  874566
#
#           user_question_record_id
#  0                        771,777
#  1                        771,800
#  2                        771,812
#  3                        771,828
#  4                        771,851
# ...

# %%
# 두 컬럼의 고유값 추출
set_ids = set(questionset['id'].unique())
piece_ids = set(questionpiece['id'].unique())

# 겹치는 ID 확인
question_ids = piece_ids.intersection(set_ids)

# 결과 출력
print(f"겹치는 ID 수: {len(question_ids)}")
# Out:
# 겹치는 ID 수: 0

# %% [markdown]
# ### userquestionrecord 테이블에서 모호한 부분을 잡아내자 (내용은 노션에 정리)

# %%
userquestionrecord
# Out:
#                 id status          created_at chosen_user_id  question_id  \
# 0           771777      C 2023-04-28 12:27:49         849469          252
# 1           771800      C 2023-04-28 12:28:02         849446          244
# 2           771812      C 2023-04-28 12:28:09         849454          183
# 3           771828      C 2023-04-28 12:28:16         847375          101
# 4           771851      C 2023-04-28 12:28:26         849477          209
# ...            ...    ...                 ...            ...          ...
# 1217553  161666166      C 2024-05-07 11:29:07         945560         2614
# 1217554  161666461      C 2024-05-08 01:34:56         850774         1679
# 1217555  161666462      C 2024-05-08 01:35:02         855509         2605
# 1217556  161666463      C 2024-05-08 01:36:00         855526         3801
# 1217557  161666464      C 2024-05-08 01:36:18         874566         3117
#
#          user_id  question_piece_id  has_read answer_status  \
# ...

# %% [markdown]
# | 컬럼명             | 설명                                   | 값 예시 / 코드 설명                          |
# |------------------|--------------------------------------|-------------------------------------------|
# | user_id          | 선택한 유저 ID                           | -                                         |
# | chosen_user_id   | 선택 받은 유저 ID                         | -                                         |
# | opened_times     | 열어본 횟수                              |                            |
# | status           | 상태 (닫힘 / 초성 열림 / 차단)              | C: Closed (닫힘) <br> I: Initial (초성 열림) <br> B: Blocked (차단) |
# | question_id      | 질문 ID                                |                            |
# | question_piece_id| 투표 ID                                |                          |
# | answer_status    | 답장 상태 (미답변 / 비공개 / 공개)          | N: Not Answered (미답변) <br> P: Private (비공개) <br> A: Available (공개) |
# | answer_updated_at| 답장 시간                               |         |
# | report_count     | 신고 횟수                               |                              |
# | has_read         | 읽었는지 여부                            |                     |
# | created_at       | 만든 시간                               |       |

# %%
userquestionrecord['opened_times'].value_counts()
# Out:
# opened_times
# 0    1156896
# 1      46882
# 2      11120
# 3       2660
# Name: count, dtype: int64

# %%
userquestionrecord['status'].value_counts()
# Out:
# status
# C    1156322
# I      60578
# B        658
# Name: count, dtype: int64

# %%
userquestionrecord['has_read'].value_counts()
# Out:
# has_read
# 1    675931
# 0    541627
# Name: count, dtype: int64

# %%
reader = userquestionrecord[userquestionrecord['has_read'] == '0']
miss = reader[reader['answer_status'] != 'N'] 
miss
# Out:
# Empty DataFrame
# Columns: [id, status, created_at, chosen_user_id, question_id, user_id, question_piece_id, has_read, answer_status, answer_updated_at, report_count, opened_times]
# Index: []

# %%
read_group = userquestionrecord[userquestionrecord['has_read'] == '1']
noread_group = userquestionrecord[userquestionrecord['has_read'] == '0']

# %%
# 먼저 has_read 컬럼이 문자열인지, 숫자인지 확인 후 정제
userquestionrecord['has_read'] = userquestionrecord['has_read'].astype(str)

# has_read == '1' 그룹
read_group = userquestionrecord[userquestionrecord['has_read'] == '1']
read_counts = read_group['answer_status'].value_counts()

# has_read == '0' 그룹
noread_group = userquestionrecord[userquestionrecord['has_read'] == '0']
noread_counts = noread_group['answer_status'].value_counts()

# 결과 출력
print("읽은 사람 (has_read == '1')의 answer_status 분포:")
print(read_counts)

print("\n안 읽은 사람 (has_read == '0')의 answer_status 분포:")
print(noread_counts)
# Out:
# 읽은 사람 (has_read == '1')의 answer_status 분포:
# answer_status
# N    556305
# A    111761
# P      7865
# Name: count, dtype: int64
#
# 안 읽은 사람 (has_read == '0')의 answer_status 분포:
# answer_status
# N    541627
# Name: count, dtype: int64

# %%
print(userquestionrecord['has_read'].unique())
# Out:
# ['0' '1']

# %%
# 실제 데이터 타입 확인
print(userquestionrecord['has_read'].dtype)
# Out:
# object

# %%
print(userquestionrecord['has_read'].value_counts(dropna=False))
# Out:
# has_read
# 1    675931
# 0    541627
# Name: count, dtype: int64

# %%
read_group
# Out:
#                 id status          created_at chosen_user_id  question_id  \
# 2           771812      C 2023-04-28 12:28:09         849454          183
# 4           771851      C 2023-04-28 12:28:26         849477          209
# 10          771940      I 2023-04-28 12:29:13         849634          297
# 19          772023      C 2023-04-28 12:30:03         849503          177
# 21          772027      C 2023-04-28 12:30:04         849634          184
# ...            ...    ...                 ...            ...          ...
# 1217376  161626230      C 2024-02-09 14:45:55        1022735          638
# 1217378  161626232      C 2024-02-09 14:46:18        1022735         2258
# 1217436  161639676      I 2024-03-09 16:52:50        1012219         4684
# 1217451  161639779      I 2024-03-10 03:28:31        1012219          202
# 1217553  161666166      C 2024-05-07 11:29:07         945560         2614
#
#          user_id  question_piece_id has_read answer_status  \
# ...

# %% [markdown]
# # 5/30 hackle 데이터 해체분석

# %%
# hackle_properties # device_properties
# user_properties # hackle_events

# %%
hackle_properties
# Out:
#             id                            session_id  \
# 0            1          4OzYh3seq3VKytpSn5pvQkZNQii1
# 1            2          8QXy31PQxbW9qLzq0Y1dhR8Ypm52
# 2            3  6bcea65d-9f40-46fc-888c-700fe707483f
# 3            4          XVYNT6zfhFWqIg9omwg2AHDjTLx2
# 4            5          XFB2SPiGfjbVhvJ3Q3DBsaT3m2B3
# ...        ...                                   ...
# 525345  525346          KlGJxOfY4XdbxnwzPckMh4NdwBk2
# 525346  525347          HGxbSi2oq4MdFVGdQx2UH3f9Aq73
# 525347  525348  F9EA195C-862F-4572-80A5-C3AE06F83310
# 525348  525349          gQ5GvGk7kGWwnQbOzQ8fxseQp8B2
# 525349  525350          8jROJMvKQMgiXMvrXvqDD7o0iWr2
#
#                              user_id language   osname osversion versionname  \
# 0                                       ko-KR      iOS      16.0       2.0.0
# 1                            1046711    ko-KR      iOS    16.5.1       2.0.3
# 2                            1545130       ko  Android        13       2.0.5
# ...

# %%
# 두 컬럼의 고유값 추출
hackle_session_id = set(hackle_properties['user_id'].unique())
user_id = set(user['id'].unique())

# 겹치는 ID 확인
common_ids = hackle_session_id.intersection(user_id)

# 결과 출력
print(f"겹치는 ID 수: {len(common_ids)}")
# 동일한 device_id임을 확인.
# Out:
# 겹치는 ID 수: 226365

# %%
questionset # user의 id 값과 questionset의 user_id 값이 중복
# Out:
#               id                             question_piece_id_list  \
# 0          99817  [998458, 998459, 998460, 998461, 998462, 99846...
# 1          99830  [998588, 998589, 998590, 998591, 998592, 99859...
# 2          99840  [998689, 998691, 998693, 998695, 998697, 99869...
# 3          99841  [998688, 998690, 998692, 998694, 998696, 99869...
# 4          99848  [998768, 998769, 998770, 998771, 998772, 99877...
# ...          ...                                                ...
# 158379  20838253  [208383291, 208383292, 208383293, 208383294, 2...
# 158380  20838344  [208384201, 208384202, 208384203, 208384204, 2...
# 158381  20838419  [208384951, 208384952, 208384953, 208384954, 2...
# 158382  20838445  [208385211, 208385212, 208385213, 208385214, 2...
# 158383  20838446  [208385221, 208385222, 208385223, 208385224, 2...
#
#               opening_time status          created_at  user_id
# 0      2023-04-28 12:27:22      F 2023-04-28 12:27:23   849436
# ...

# %%
questionset['user_id'].nunique()
# Out:
# 4972

# %%
user_session_counts = hackle_properties.groupby('user_id')['session_id'].nunique().reset_index()
user_session_counts.columns = ['user_id', 'session_count']
user_session_counts.value_counts().reset_index().sort_values(by='count', ascending=False)
# user_id에 따라 세선 id가 몇 개인지 확인. session_id는 유저의 고유 id인 걸로 확인할 수 있음.
# Out:
#                              user_id  session_count  count
# 327380  011n4KVVKlWyW9ph0UMNjcQ6voq2              1      1
# 0       zzzYYwN42NdbhcyXHgyeAxyNH7J2              1      1
# 1                                             78197      1
# 2       001zjRPEGWWVou4CbhLU7JQ9K9W2              1      1
# 3       002KHtytQcVvLzOzvprOv0sxVTM2              1      1
# ...                              ...            ...    ...
# 24      zxuXNt2xGVfohlx3SJOyJUi8xP22              1      1
# 25      zxv4QlTLN8Zja9fixE8shXgc8xJ2              1      1
# 26      zxwfc1jk3EXAunvnD8BjXfEvjSl2              1      1
# 27      zxwhME408HOUR4OW0LPwSzmT8di1              1      1
# 28      zy2wvThdtHRubg3nCfOB0DyFkxu1              1      1
#
# [327381 rows x 3 columns]

# %%
# hackle_properties['session_id'].unique().sum()

# %%
hackle_properties['language'].unique() #언어의 종류가 굉장히 많음. 왜지? 단기간의 서비스 동안 세계 정복이라도 했나?
# 비율로 한 번 보고 싶어졌다.
# Out:
# array(['ko-KR', 'ko', 'ko-US', 'ko-JP', 'en-KR', 'zh-Hans-CN', 'ko-NI',
#        'zh-Hans-KR', 'ko-CA', 'ru-KR', 'en-US', 'ko-FI', 'ko-GU', 'ja-KR',
#        'en', 'ko-GH', 'en-GB', 'ko-GP', 'ko-CN', 'ko-NF', 'ko-PH',
#        'ja-JP', 'ko-GA', 'ko-GG', 'ko-DG', 'ko-GM', 'ko-GT', 'en-NZ',
#        'ko-VC', 'ko-GB', 'ru-RU', 'ko-AU', 'ko-DZ', 'ko-VN', 'ja',
#        'ko-DM', 'en-GP', 'la-KR', 'ko-KH', 'ko-DE', 'vi-KR', 'ko-AR',
#        'en-AE', 'ko-GY', 'ko-SA', 'ko-BR', 'ko-RU', 'ko-UM', 'ko-CI',
#        'es', 'ko-MY', 'en-MW', 'ko-AE', 'ko-MR', 'ko-MM', 'en-CA',
#        'ko-GD', 'ko-SR', 'ko-ES', 'ko-ZA', 'es-419', 'en-AR', 'ko-SG',
#        'ko-AM', 'ko-BQ', 'ko-FR', 'fr-KR', 'ko-LV', 'vi', 'zh', 'ru',
#        'en-AU', 'ko-IT', 'en-JP', 'ko-NZ', 'es-JP', 'de-KR', 'en-IN',
#        'ko-FK', 'ko-HK', 'ko-GL', 'ko-NA', 'en-SG', 'ru-KZ', 'en-AM',
#        'zh-Hans-US', 'en-ZA', 'en-AS', 'ko-KE', 'ko-TH', 'ko-DK', 'ru-UZ',
# ...

# %%
language_counts = hackle_properties['language'].value_counts()
language_percent = (language_counts / language_counts.sum()) * 100

# 상위 5 언어만
top_5 = 5
top_languages = language_percent[:top_5]
other_percent = 100 - top_languages.sum()

# 파이차트용 라벨 + 기타 묶기
labels = list(top_languages.index) + ['기타']
sizes = list(top_languages.values) + [other_percent]

# 시각화
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('언어별 사용자 비율')

plt.show()

# 비율 출력
print(" 언어별 사용자 비율 상위 10:")
print(top_languages.round(2).astype(str) + ' %')
# Out:
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# /home/hq_key/codeit-project-docker/hackle/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 50616 (\N{HANGUL SYLLABLE EON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hq_key/codeit-project-docker/hackle/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hq_key/codeit-project-docker/hackle/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# 한국어 설정이 압도적으로 많긴 하지만 극 소수의 외국 유저가 있음. 핸드폰 기본 설정을 영어로 하는 힙스터가 존재할 수도 있다고 생각함.
# 혹은 vpn ?

# %%
hackle_properties['osname'].unique() # MZ들은 아이폰 삼성 뺴곤 폰으로 안치는 모습.
# Out:
# array(['iOS', 'Android'], dtype=object)

# %%
hackle_properties['device_id'].unique() # 각 디바이스 고유 id라고 생각하여 이용자 수와 같은 값이 나올 것이라 생각했는데 의외의 결과가 나옴    
# 같은 핸드폰 기종이라면 같은 id를 가지는가 ?
# Out:
# array(['590E7C79-CBA0-44D8-8BE3-3C9BFABBBC74',
#        'D5417226-F71B-4A9E-A180-CD072F2AB279',
#        '6bcea65d-9f40-46fc-888c-700fe707483f', ...,
#        '2fb48c61-4b30-43df-af55-6db388b1b3d7',
#        '6E822BC8-539F-4525-A39E-DCD458BA378B',
#        '0F389376-CBE1-4AA4-A562-36AA0E8C5821'], dtype=object)

# %%
hackle_properties['device_id'].duplicated().sum() # 중복된 device_id의 개수
# Out:
# 273630

# %%
device_properties # hackle_properties의 device_id와 동일한 id를 가지는지 확인하고 싶었음
# Out:
#             id                             device_id device_model  \
# 0            1  000007C9-E103-4EB5-9777-A9084D4952DF   iPhone14,7
# 1            2  00002245-458F-4CDD-8533-B448CD43DBD2   iPhone14,7
# 2            3  00012620-313A-4502-9F8D-8DAB7443215B   iPhone14,5
# 3            4  000137bc-80de-4bb5-b61d-df7f217a4501     SM-F711N
# 4            5  000227D6-B782-4367-91C4-486B76DF9E37   iPhone12,3
# ...        ...                                   ...          ...
# 252375  252376  FFFE54E6-48F9-4262-A487-94E944B1B68C   iPhone14,4
# 252376  252377  FFFE80D2-6B57-41AF-9CD6-8E616CC7BFDE   iPhone14,7
# 252377  252378  FFFED16A-DAF6-40A1-865D-29C4D1302DA5   iPhone14,4
# 252378  252379  FFFEEA5E-C4D9-4BB7-A9E4-3715455B69AD   iPhone12,8
# 252379  252380  FFFEF44A-ADDD-42BB-9594-698C10FDDDA9   iPhone13,2
#
#        device_vendor
# 0              Apple
# 1              Apple
# 2              Apple
# 3            samsung
# 4              Apple
# ...              ...
# ...

# %%
# 두 컬럼의 고유값 추출
device_id_id = set(hackle_properties['device_id'].unique())
id_id = set(device_properties['device_id'].unique())

# 겹치는 ID 확인
common_ids = id_id.intersection(device_id_id)

# 결과 출력
print(f"겹치는 ID 수: {len(common_ids)}")
# 동일한 device_id임을 확인.
# Out:
# 겹치는 ID 수: 251720

# %%
device_properties['device_vendor'].unique() # 운영체제와 제조사는 다를 수 있다는 사실을 여기서 알게 되었다;
# Out:
# array(['Apple', 'samsung', 'Lenovo', 'LGE', 'Xiaomi', 'blackshark',
#        'Google', 'FYD', 'Samsung', 'Chinoe', 'vivo', 'ZTE', 'OnePlus',
#        'motorola', 'Foxconn', 'Shanling', 'Teclast', 'Nothing', 'Amazon',
#        'LENOVO', 'HUAWEI', 'vsmart', 'Digital', 'Sony', 'bnd',
#        'Alldocube', 'Teclast_korea', 'incar', 'asus', 'E-dong', 'realme',
#        'APEX', 'Razer', 'HXY', 'IMUZ', 'iMUZ'], dtype=object)

# %%
user_properties  # school_id와 user_id를 엮어서 어떤 학교에 다니는 학생인지 엮고 user_id를 통해 여러가지 데이터를 merge하면 어떤 질문을 했는지 결제를 했는지 어떤 이벤트에 참여했는 지 알 수 있지 않을까 ?
# Out:
#                              user_id  class gender  grade  school_id
# 0                            1000000      1      M      1       1885
# 1                            1000009     10      F      2       3869
# 2                            1000012     10      F      1       5091
# 3                            1000013      8      F      2       1743
# 4                            1000015      2      F      3       5078
# ...                              ...    ...    ...    ...        ...
# 230814                        999992      1      M      2       2240
# 230815                        999996      5      M      2        365
# 230816                        999997      2      M      3       2502
# 230817  nhj4wh46MAf5K0IHDu4DGyRsdWn2      5      F      2       3499
# 230818  nmbzA4awkiRGXX26fT6wpoxURY43      1      F      1       5407
#
# [230819 rows x 5 columns]

# %%
school # user_properties와 school을 엮어서 어떤 학교에 다니는 학생인지 알 수 있다.
# Out:
#         id   address  student_count school_type
# 0        4  충청북도 충주시            239           H
# 1        5  충청북도 충주시            160           M
# 2        6  충청북도 충주시            200           H
# 3        7  충청북도 충주시            114           H
# 4        8  충청북도 충주시            139           M
# ...    ...       ...            ...         ...
# 5946  5960  경상남도 양산시            166           H
# 5947  5961  인천광역시 서구             77           M
# 5948  5963  경상북도 김천시             17           H
# 5949  5964         -              1           H
# 5950  5965  경기도 동두천시             37           H
#
# [5951 rows x 4 columns]

# %%
# 두 테이블이 school과 user라고 가정
school_ids_1 = set(school['id'])
school_ids_2 = set(user_properties['school_id'])

# 교집합 (중첩되는 school_id)
common_ids = school_ids_1 & school_ids_2

# 차집합 (school 테이블에만 있는 school_id)
only_in_school = school_ids_1 - school_ids_2

# 차집합 (user 테이블에만 있는 school_id)
only_in_user = school_ids_2 - school_ids_1

# 출력
print(f"중첩되는 school_id 개수: {len(common_ids)}")
print(f"school 테이블에만 있는 school_id 개수: {len(only_in_school)}")
print(f"user 테이블에만 있는 school_id 개수: {len(only_in_user)}")
# 그렇다면 2개의 school_id 예외 사항을 제외한 나머지 user_id에는 user_properties를 기준으로 user_id에 어떤 지역 학생인지 엮을 수 있다.
# Out:
# 중첩되는 school_id 개수: 5021
# school 테이블에만 있는 school_id 개수: 930
# user 테이블에만 있는 school_id 개수: 2

# %%
school.rename(columns={'id': 'school_id'}, inplace=True)
school['student_count'].describe()
# 학생 수 평균
# Out:
# count   5,951
# mean      114
# std       103
# min         0
# 25%        16
# 50%        97
# 75%       183
# max       578
# Name: student_count, dtype: float64

# %%
# school_id를 기준으로 내부 조인 (중첩된 것만 합치기)
school.rename(columns={'id': 'school_id'}, inplace=True)
school_id_merged = pd.merge(user_properties, school, on='school_id', how='inner')
school_id_merged
# Out:
#         user_id  class gender  grade  school_id       address  student_count  \
# 0       1000000      1      M      1       1885      서울특별시 중구            106
# 1       1013675      9      M      2       1885      서울특별시 중구            106
# 2       1017935      9      M      2       1885      서울특별시 중구            106
# 3       1024285      9      M      2       1885      서울특별시 중구            106
# 4       1027540      9      M      1       1885      서울특별시 중구            106
# ...         ...    ...    ...    ...        ...           ...            ...
# 230779   975861      1      F      3        325      충청남도 예산군              3
# 230780   980083      2      F      3       5629       경기도 가평군              3
# 230781   982772      7      M      2       2053     서울특별시 송파구             16
# 230782   984113     18      F      2       4065  경상남도 창원시 의창구             13
# 230783   998504      2      F      3       2367     서울특별시 구로구             18
#
#        school_type
# 0                H
# ...

# %%
# address 앞 3글자 → 지역명 추출
school_id_merged['region'] = school_id_merged['address'].str[:3]

region_counts = school_id_merged['region'].value_counts().sort_values(ascending=False)

# 시각화
region_counts.plot(kind='bar', color='cornflowerblue', edgecolor='black')

plt.title('시/도별 학생 수')
plt.xlabel('시/도')
plt.ylabel('학생 수')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# /tmp/ipykernel_488632/3438811071.py:13: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_488632/3438811071.py:13: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_488632/3438811071.py:13: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# findfont: Font family 'NanumGothicCoding' not found.
# /tmp/ipykernel_488632/3438811071.py:13: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_488632/3438811071.py:13: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %% [markdown]
#  전국에 고등학교가 얼마나 분포되어 있는 지 외부 데이터를 통해 확인해보고 싶다. 경기도만 이렇게 많은 학생 수를 나타내는 것은 조금 이상하다고 보임.

# %%
user_properties['grade'].value_counts() # 123학년의 정보만 얻을 수 있었고 middle school, high school, elementary school의 정보는 얻을 수 없었다.
# Out:
# grade
# 2    96778
# 3    67274
# 1    66767
# Name: count, dtype: int64

# %%
hackle_events
# Out:
#                                       event_id      event_datetime  \
# 0         00000533-3f1c-4b3b-81f1-0c8f35754b4e 2023-07-18 19:40:17
# 1         00000716-27e9-4e72-a602-d0ce61784b06 2023-07-18 21:07:24
# 2         000007c8-68ce-40e6-9b1e-f0e34e8ff9cc 2023-08-06 20:18:03
# 3         00000981-5e2a-4111-993e-4f1891ad9a53 2023-08-05 01:46:10
# 4         00000a7a-ba72-4332-b4a9-7910670aaeb2 2023-07-24 15:03:37
# ...                                        ...                 ...
# 11441314  fffff54e-e730-418f-8080-4eff7e2641f2 2023-08-08 01:40:00
# 11441315  fffff57d-6c79-46b3-a87b-4bfa900ef11b 2023-07-23 09:30:22
# 11441316  fffff632-2d70-4190-addd-6ae2f2399876 2023-07-18 18:13:30
# 11441317  fffffb07-af2f-4cce-a26e-1dcc97c74b14 2023-07-21 15:37:27
# 11441318  fffffeac-675f-4c6e-900a-a422ed9bd57c 2023-07-22 02:31:16
#
#                                 event_key  \
# 0                          $session_start
# 1                     click_question_open
# ...

# %%
event_counts = hackle_events['event_key'].value_counts()

import matplotlib.pyplot as plt
import seaborn as sns



# 시각화 설정
plt.figure(figsize=(12, 6))
sns.barplot(x=event_counts.index, y=event_counts.values, palette='viridis')

# 제목 및 라벨
plt.title('이벤트 발생 빈도수 (event_key 기준)', fontsize=16)
plt.xlabel('Event Key', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# 이벤트 발생 빈도수
# Out:
# /tmp/ipykernel_488632/1531674554.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=event_counts.index, y=event_counts.values, palette='viridis')
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# ...

# %% [markdown]
# 1. view_lab_tap                         1266665  - 실험실 탭에 진입
# 2. view_timeline_tap                    1194508  - 타임라인 화면 진입
# 3. $session_start                       1036852  - 세션 시작
# 4. launch_app                            986388  - 앱 실행
# 5. click_question_open                   816801  - 홈 화면에서 ask 클릭

# %%
# hackle_events	friend_count	votes_count

hackle_events['friend_count'].value_counts()
# Out:
# friend_count
# 0        260578
# 42       167043
# 34       166160
# 50       165094
# 36       163511
#           ...
# 313           2
# 278           2
# 1,365         2
# 330           2
# 291           2
# Name: count, Length: 370, dtype: int64

# %%
hackle_events['friend_bin'] = pd.cut(hackle_events['friend_count'], bins=[0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700],)
hackle_events['friend_bin'].value_counts()

avg_votes_per_bin = hackle_events.groupby('friend_bin')['votes_count'].mean().sort_index()


avg_votes_per_bin.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('친구 수 구간별 평균 투표 수')
plt.xlabel('Friend Count 구간')
plt.ylabel('Average Votes Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# 친구가 많을 수록 투표도 많이 받지 않을까?
# Out:
# /tmp/ipykernel_488632/104877045.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_votes_per_bin = hackle_events.groupby('friend_bin')['votes_count'].mean().sort_index()
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# ...

# %% [markdown]
# 300~350명을 넘어가는 순간 평균 투표 수가 급감한다. 왜일까? 광고계정?
# question 테이블에서 질문 내용을 확인했을 때 투표 대상이 어떤 사람인지 알거나 그 사람에 대해 좀 알아야 투표를 할 수 있는 내용의 질문이 대다수였다.
# 이를 통해 같은 학교여야 투표가 가능하다고 생각했다. 그럼 학교 당 이용자 수가 300~350명 수준인가?

# %%
school['student_count']

school['student_bin'] = pd.cut(school['student_count'], bins=[0, 50, 100, 150, 200, 250, 300, 350, 1000],)


student_bin_counts = school['student_bin'].value_counts().sort_index()

student_bin_counts.plot(kind='bar', color='mediumseagreen', edgecolor='black')

plt.title('학생 수 구간별 분포')
plt.xlabel('학생 수 구간')
plt.ylabel('학교 수')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# findfont: Font family 'NanumGothicCoding' not found.
# /tmp/ipykernel_488632/1732501383.py:14: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_488632/1732501383.py:14: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %% [markdown]
# 학교 당 이 서비스를 이용하는 학생 수는 0~50명의 값이 가장 많음.
# 그렇다면 혹시 주변 학교들에도 지인이 있을 수 있으니 nearbyschool 데이터로 주변 학교들을 묶으면 300~350명 정도의 학생 수가 평균적으로 나오나 ? 추후 고민해 볼 만 하다
# 또 생각해 볼 수 있는 경우는 성인들의 경우 학교에 잡히지 않아 집계되지 않았을 경우.
# 성인 이용자가 있다면 또 데이터가 다르게 수집되지 않을까?
# 성인의 데이터는 어떻게 수집해야 하는가.

# %%
# 간단하게 vote 테이블의 user 테이블과 school의 학생 수 비교
user  # user에 잡히는 id 값 677085개
# Out:
#              id  is_superuser  is_staff gender  point  \
# 0        831956             1         1   None    600
# 1        831962             0         0      F   2248
# 2        832151             0         0      M   1519
# 3        832340             0         0      F     57
# 4        832520             0         0      M   1039
# ...         ...           ...       ...    ...    ...
# 677080  1583729             0         0      M    300
# 677081  1583730             0         0      M    420
# 677082  1583731             0         0      M    300
# 677083  1583732             0         0      F    300
# 677084  1583733             0         0      F    300
#
#                                            friend_id_list  is_push_on  \
# 0       [1292473, 913158, 1488461, 1064695, 1043565, 1...           0
# 1       [833025, 832642, 982531, 879496, 838541, 83752...           1
# 2       [838785, 982531, 882567, 879496, 838541, 83649...           0
# ...

# %%
school['student_count'].sum() # 학생임을 인증하고 이용해야 하는가 ?
# Out:
# 677063

# %% [markdown]
# 총 user 수와 school의 student_count 값이 차이가 거의 없는 걸로 보아 학생임을 인증하고 이용한다는 가이드 내용과 일치함.

# %% [markdown]
# # session_id를 유저 고유 id로 정의 -> 인사이트를 얻을 수 있는 부분을 찾아보자 x
# ### user_id가 유저 고유 id로 밝혀짐 - user_id가 비어있는 경우 -> device_id와 session_id를 통해 채워넣기, user의 user_id는 str로 변환

# %%
# hackle_events와 hackle_properties를 병합(session_id로 left join + session_id와 device_id를 통해 user_id 채워넣고 그래도 빈 값은 제거한 데이터+중복제거)
final_hackle = pd.read_parquet('/home/hq_key/codeit-project-docker/final.parquet')

# %%
final_hackle.user_id.isna().sum()
# Out:
# 0

# %%
final_hackle
# Out:
#                                       event_id      event_datetime  \
# 0         00000533-3f1c-4b3b-81f1-0c8f35754b4e 2023-07-18 19:40:17
# 1         00114c10-8321-4978-a73f-fd452162b9f2 2023-07-31 19:11:51
# 2         01f136ac-3257-4cf9-b0a9-c0c37fe7e572 2023-07-31 19:14:34
# 3         02cc364e-23ec-46cf-a02f-14cf60f97ec1 2023-07-31 19:13:18
# 4         05d05a79-cdb3-43fe-b931-5cb0992a36a1 2023-07-31 19:12:50
# ...                                        ...                 ...
# 11406939  fcc5da6e-6aff-4bad-afaa-387266dd3b2e 2023-07-21 08:07:34
# 11406940  fdb9051e-fc66-419d-b086-b6ecf8b34157 2023-07-21 08:07:34
# 11406941  fcd2ca57-88fc-48e5-b7cc-6ed78de0458f 2023-07-28 01:29:54
# 11406942  fd1c8cbc-a857-405b-96dd-dfa4533e6875 2023-08-05 17:10:41
# 11406943  ff6ae0d2-63df-40af-b326-a501da233cce 2023-08-05 17:10:41
#
#                     event_key                            session_id  \
# 0              $session_start          4OzYh3seq3VKytpSn5pvQkZNQii1
# ...

# %%
hackle_events.session_id.duplicated().sum() # 중복된 session_id의 개수
# Out:
# 11187703

# %%
# events = hackle_events[['event_datetime','event_key','session_id','heart_balance']]
# properties = hackle_properties[['session_id','user_id','device_id']]

# df = events.merge(properties,on='session_id',how='left')

# # user_id가 ''인 경우는 결측치로 처리
# df['user_id'] = df['user_id'].replace('', pd.NA)

# # 동일한 session_id + device_id 조합으로 user_id가 있는 값 추출
# lookup = (
#     df[df['user_id'].notna()]
#     .groupby(['session_id', 'device_id'])['user_id']
#     .first()
#     .reset_index()
# )

# # 원래 df에 join해서 빈 user_id 채우기
# df = df.merge(lookup, on=['session_id', 'device_id'], how='left', suffixes=('', '_fill'))

# # user_id가 비어있던 경우에만 fill된 값으로 대체
# df['user_id'] = df['user_id'].combine_first(df['user_id_fill'])
# #
# # 보조 컬럼 삭제
# df.drop(columns=['user_id_fill'], inplace=True)


# df = df.dropna(subset=['user_id'])

# %%
df['user_id'].nunique() ,df['user_id'].isna().sum()  # 결측치가 없는지 확인
# Out:
# (115, 0)

# %%
import pandas as pd

# 1. heart_balance가 NaN인 user_id 추출
sessions_with_nan = final_hackle[final_hackle['heart_balance'].isna()]['user_id'].unique()

# 2. 해당 세션들 중에서 heart_balance가 존재하는 행만 필터링
valid_heart_sessions = final_hackle[
    final_hackle['user_id'].isin(sessions_with_nan) & 
    final_hackle['heart_balance'].notna()
]['user_id'].unique()

# 
print("✔️ heart_balance가 NaN과 값이 함께 존재하는 세션 수:")
print(len(set(valid_heart_sessions)))
# Out:
# ✔️ heart_balance가 NaN과 값이 함께 존재하는 세션 수:
# 133741

# %%
final_hackle['user_id'].nunique()  # 전체 세션 수
# 너무 많은 NaN 값이 세션에 섞여 있음.
# Out:
# 239650

# %%
target_id = '1041414'

# 해당 id에 해당하는 행 추출
target_df = final_hackle[final_hackle['user_id'] == target_id][['event_key', 'event_datetime', 'heart_balance']].sort_values(by='event_datetime')

# 출력
print(target_df)
# Out:
#                            event_key      event_datetime  heart_balance
# 0                     $session_start 2023-07-18 19:40:17            NaN
# 13                        launch_app 2023-07-18 19:40:17            NaN
# 44                      $session_end 2023-07-18 19:40:17            NaN
# 21                    $session_start 2023-07-18 19:40:21            NaN
# 29                        launch_app 2023-07-31 19:11:17          1,708
# ..                               ...                 ...            ...
# 6   click_bottom_navigation_timeline 2023-07-31 19:15:21          1,719
# 41       click_bottom_navigation_lab 2023-07-31 19:15:26          1,719
# 35                      view_lab_tap 2023-07-31 19:15:26          1,719
# 9                   view_profile_tap 2023-07-31 19:15:28          1,719
# 23   click_bottom_navigation_profile 2023-07-31 19:15:28          1,719
#
# [61 rows x 3 columns]

# %%
final_hackle['heart_balance'].isnull().sum()
# Out:
# 696462

# %%
final_hackle['heart_balance'].value_counts().sum()
# Out:
# 10710482

# %%
import pandas as pd

# 사전 정렬
df = final_hackle[['user_id', 'event_key', 'event_datetime', 'heart_balance']].copy()
df = df.sort_values(['user_id', 'event_datetime'])

# 이전 하트 잔액, 이벤트 키, 시간 계산
df['heart_balance_prev'] = df.groupby('user_id')['heart_balance'].shift(1)
df['event_key_prev'] = df.groupby('user_id')['event_key'].shift(1)
df['event_datetime_prev'] = df.groupby('user_id')['event_datetime'].shift(1)

# 변화량 계산 공식
df['heart_balance_diff'] = df['heart_balance'] - df['heart_balance_prev']

# NaN 이전 값을 채우기
df['heart_balance'] = df['heart_balance'].fillna(method='ffill')

# NaN 제거 & 변화가 있는 경우만 골라내기
result_df = df[
    df['heart_balance_diff'].notnull() &
    (df['heart_balance_diff'] != 0)
].copy()



# 원하는 컬럼만 정리
result_df = result_df[[
    'user_id',
    'event_key_prev', 'event_datetime_prev', 'heart_balance_prev',
    'event_key', 'event_datetime', 'heart_balance',
    'heart_balance_diff'
]]

result_df
# Out:
# /tmp/ipykernel_488632/3876281811.py:16: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['heart_balance'] = df['heart_balance'].fillna(method='ffill')
#          user_id                   event_key_prev event_datetime_prev  \
# 7119300  1000013                       view_login 2023-07-20 01:04:42
# 1393712  1000030                        view_shop 2023-07-29 01:01:09
# 1393656  1000030                       launch_app 2023-07-30 15:55:00
# 3282467  1000044                       launch_app 2023-07-18 18:08:53
# 9573354  1000069                        view_shop 2023-07-20 21:53:46
# ...          ...                              ...                 ...
# 9952327   999940                       view_login 2023-07-18 19:33:34
# 8425700   999946                   $session_start 2023-07-19 01:43:07
# 6991192   999976                   $session_start 2023-07-18 12:36:27
# ...

# %%
# 하트 변화가 가장 자주 발생한 이벤트 순위
event_change_freq = result_df['event_key'].value_counts().reset_index()
event_change_freq.columns = ['event_key', 'change_count']

# 상위 10개만 보기
top_10_change_events = event_change_freq.head(10)

print("🔥 하트 변화가 자주 발생한 이벤트 Top 10:")
print(top_10_change_events)
# question_open에서 하트 변화가 일어나는 지 확인하기`
# Out:
# 🔥 하트 변화가 자주 발생한 이벤트 Top 10:
#                            event_key  change_count
# 0                click_question_open         16691
# 1                     click_purchase          6782
# 2                         launch_app          6762
# 3               click_question_start          5687
# 4                   click_attendance          5622
# 5                  view_timeline_tap          5522
# 6          click_appbar_alarm_center          5312
# 7                       $session_end          4037
# 8  click_bottom_navigation_questions          3800
# 9                       view_lab_tap          2610

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설정
plt.rc('font', family='Malgun Gothic')
# 또는 시스템에 설치된 다른 한글 폰트 이름 사용
# 시각화
plt.figure(figsize=(10, 6))
sns.set(style='whitegrid')

# 막대 그래프
sns.barplot(
    data=top_10_change_events,
    x='change_count',
    y='event_key'
)

# 제목 및 레이블
plt.title(' 하트 변화가 자주 발생한 이벤트 Top 10', fontsize=14, fontweight='bold',fontproperties=fontprop)
plt.xlabel('변화 횟수',fontproperties=fontprop)
plt.ylabel('이벤트 이름',fontproperties=fontprop)

# 값 표시
for index, value in enumerate(top_10_change_events['change_count']):
    plt.text(value + 1, index, str(value), va='center')

plt.tight_layout()
plt.show()

# %%
# 하트 획득이 자주 발생한 이벤트
earned_events = result_df[result_df['heart_balance_diff'] > 0]
earned_freq = earned_events['event_key'].value_counts().head(10)

# 하트 소모가 자주 발생한 이벤트
spent_events = result_df[result_df['heart_balance_diff'] < 0]
spent_freq = spent_events['event_key'].value_counts().head(10)

earned_freq
# Out:
# event_key
# click_question_open                  11393
# click_question_start                  3666
# click_appbar_alarm_center             3664
# view_timeline_tap                     3297
# click_attendance                      3207
# click_purchase                        2787
# click_bottom_navigation_questions     2580
# launch_app                            2569
# $session_end                          2136
# click_appbar_chat_rooms               1583
# Name: count, dtype: int64

# %%
spent_freq
# Out:
# event_key
# click_question_open                  5298
# launch_app                           4193
# click_purchase                       3995
# click_attendance                     2415
# view_timeline_tap                    2225
# click_question_start                 2021
# $session_end                         1901
# click_appbar_alarm_center            1648
# click_bottom_navigation_questions    1220
# $session_start                       1031
# Name: count, dtype: int64

# %%
import pandas as pd

# 확인하고 싶은 이벤트 키 목록
target_event_keys = [
    'complete_question',
    'click_question_start',
]

# 하트 변화가 있고, 해당 이벤트 키에 포함되는 경우만
filtered_df = result_df[
    result_df['event_key'].isin(target_event_keys)
].copy()

# 결과 출력
print(f"선택한 이벤트 키({len(target_event_keys)}개)에서 하트 변화가 발생한 경우:")
print(filtered_df[['event_key', 'heart_balance_prev', 'heart_balance', 'heart_balance_diff']].head())
# Out:
# 선택한 이벤트 키(2개)에서 하트 변화가 발생한 경우:
#                     event_key  heart_balance_prev  heart_balance  \
# 3960329  click_question_start               3,964          3,831
# 7353952  click_question_start               1,446          1,146
# 6729640  click_question_start               3,645          1,545
# 7987779  click_question_start              11,270         12,209
# 5003334  click_question_start                 382            800
#
#          heart_balance_diff
# 3960329                -133
# 7353952                -300
# 6729640              -2,100
# 7987779                 939
# 5003334                 418

# %%
import pandas as pd

# 하트 소모 이벤트만 필터링
consumed_df = result_df[result_df['heart_balance_diff'] < 0].copy()

# 소모량 절댓값 추가
consumed_df['heart_spent'] = consumed_df['heart_balance_diff'].abs()

# ✅ 현재 이벤트 + 직전 이벤트 조합 기준으로 집계
summary = consumed_df.groupby(['event_key_prev', 'event_key']).agg(
    total_spent=('heart_spent', 'sum'),
    average_spent=('heart_spent', 'mean'),
    count=('heart_spent', 'count')
).sort_values(by='total_spent', ascending=False)

# 상위 10개 조합 출력
top_10 = summary.head(10)

print("💥 하트 소모량 기준 Top 10 이벤트 조합 (직전 + 현재):")
print(top_10.reset_index())
# Out:
# 💥 하트 소모량 기준 Top 10 이벤트 조합 (직전 + 현재):
#                 event_key_prev                        event_key  total_spent  \
# 0  click_bottom_navigation_lab                       launch_app  703,120,238
# 1                 $session_end                   $session_start   20,234,374
# 2                 $session_end  click_bottom_navigation_profile    9,990,125
# 3                    view_shop                       launch_app    2,350,825
# 4                    view_shop                   click_purchase    2,230,269
# 5                   view_login              click_question_open    1,971,871
# 6                    view_shop                     $session_end      779,044
# 7                    view_shop              click_question_open      723,259
# 8                   view_login        click_appbar_alarm_center      618,123
# 9                    view_shop                 click_attendance      591,530
#
#    average_spent  count
# 0    140,624,048      5
# 1         67,448    300
# ...

# %%
import pandas as pd

target_id = 849436

user_df = pointhistory[pointhistory['user_id'] == target_id].copy()

user_df = user_df.sort_values(by='created_at')

user_df['user_question_record_id'].duplicated().sum()

user_df
# Out:
# Empty DataFrame
# Columns: [id, delta_point, created_at, user_id, user_question_record_id]
# Index: []

# %%
pointhistory.user_question_record_id.isna().sum()
# Out:
# 2992

# %%
paymenthistory
# Out:
#           id   productId phone_type          created_at  user_id
# 0          6   heart.777          A 2023-05-13 21:28:34  1211127
# 1          7   heart.777          A 2023-05-13 21:29:39  1151343
# 2          8   heart.777          A 2023-05-13 21:31:33  1002147
# 3          9   heart.777          A 2023-05-13 21:31:39  1095040
# 4         11   heart.777          A 2023-05-13 21:34:32  1164081
# ...      ...         ...        ...                 ...      ...
# 95135  98074   heart.777          I 2024-05-06 14:51:27  1086654
# 95136  98075  heart.1000          I 2024-05-06 16:06:30   871740
# 95137  98076  heart.1000          I 2024-05-08 06:57:23  1166361
# 95138  98077  heart.1000          I 2024-05-08 14:12:45  1163480
# 95139  98078  heart.1000          I 2024-05-08 14:12:45  1163480
#
# [95140 rows x 5 columns]

# %%
# 두 컬럼의 고유값 추출
paymenthistory_id = set(paymenthistory['user_id'].unique())
user_id = set(user['id'].unique())

# 겹치는 ID 확인
common_ids = hackle_session_id.intersection(user_id)

# 결과 출력
print(f"겹치는 ID 수: {len(common_ids)}")
# 동일한 device_id임을 확인.
# user,paymenthistory,question
# Out:
# 겹치는 ID 수: 226365

# %%
target_id = '8QXy31PQxbW9qLzq0Y1dhR8Ypm52'
# 8QXy31PQxbW9qLzq0Y1dhR8Ypm52,6bcea65d-9f40-46fc-888c-700fe707483f,XVYNT6zfhFWqIg9omwg2AHDjTLx2,XFB2SPiGfjbVhvJ3Q3DBsaT3m2B3
# 해당 id에 해당하는 행 추출
target_df = hackle_events[hackle_events['session_id'] == target_id][['event_key', 'event_datetime', 'heart_balance']].sort_values(by='event_datetime')

# 출력
print(target_df)
# Out:
#                                   event_key      event_datetime  heart_balance
# 115062                       $session_start 2023-07-18 21:01:38            NaN
# 9822745                          launch_app 2023-07-18 21:01:38            NaN
# 1021516                        $session_end 2023-07-18 21:01:38            NaN
# 3968010                      $session_start 2023-07-18 21:01:42            NaN
# 7724707                          launch_app 2023-07-18 21:02:05          4,830
# 9060302                 click_question_open 2023-07-18 21:02:46          4,830
# 7795905           click_appbar_alarm_center 2023-07-18 21:02:54          4,830
# 10431301                click_notice_detail 2023-07-18 21:02:59          4,830
# 10998502   click_bottom_navigation_timeline 2023-07-18 21:03:56          4,830
# 1681578                        view_lab_tap 2023-07-18 21:04:10          4,830
# 843549          click_bottom_navigation_lab 2023-07-18 21:04:10          4,830
# ...

# %% [markdown]
# # 가설 - 질문에 많이 참여한 유저가 헤비유저일 때 헤비유저의 과금양 확인

# %%
user.id.nunique(), userquestionrecord.user_id.nunique() , questionpiece.id.nunique(), questionreport.question_id.nunique(), question.id.nunique(), usercandidate.user_id.nunique(),\
paymenthistory.user_id.nunique() , questionset.user_id.nunique()
# Out:
# (677085, 4849, 1265476, 3135, 5025, 19994, 59192, 4972)

# %%
hackle_properties.user_id.nunique(), user.id.nunique(), user_properties.user_id.nunique(), paymenthistory.user_id.nunique(), pointhistory.user_id.nunique(), questionset.user_id.nunique(), questionreport.question_id.nunique(), questionpiece.id.nunique(), usercandidate.user_id.nunique()
# Out:
# (327381, 677085, 230819, 59192, 5037, 4972, 3135, 1265476, 19994)

# %%
questionset_id = set(questionset['user_id'].unique())
user_id = set(user['id'].unique())

# 겹치는 ID 확인
common_ids = questionset_id.intersection(user_id)

# 결과 출력
print(f"겹치는 ID 수: {len(common_ids)}")
# Out:
# 겹치는 ID 수: 4972

# %%
questionset
# Out:
#               id                             question_piece_id_list  \
# 0          99817  [998458, 998459, 998460, 998461, 998462, 99846...
# 1          99830  [998588, 998589, 998590, 998591, 998592, 99859...
# 2          99840  [998689, 998691, 998693, 998695, 998697, 99869...
# 3          99841  [998688, 998690, 998692, 998694, 998696, 99869...
# 4          99848  [998768, 998769, 998770, 998771, 998772, 99877...
# ...          ...                                                ...
# 158379  20838253  [208383291, 208383292, 208383293, 208383294, 2...
# 158380  20838344  [208384201, 208384202, 208384203, 208384204, 2...
# 158381  20838419  [208384951, 208384952, 208384953, 208384954, 2...
# 158382  20838445  [208385211, 208385212, 208385213, 208385214, 2...
# 158383  20838446  [208385221, 208385222, 208385223, 208385224, 2...
#
#               opening_time status          created_at  user_id
# 0      2023-04-28 12:27:22      F 2023-04-28 12:27:23   849436
# ...

# %%
questionset['month'] = questionset['created_at'].dt.to_period('M')
questionset['month'].value_counts().sort_index().plot(kind='bar', figsize=(12, 6), title='월별 Questionset 생성 분포')
# Out:
# <Axes: title={'center': '월별 Questionset 생성 분포'}, xlabel='month'>
# /home/hq_key/codeit-project-docker/hackle/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /home/hq_key/codeit-project-docker/hackle/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /home/hq_key/codeit-project-docker/hackle/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /home/hq_key/codeit-project-docker/hackle/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 날짜 데이터가 datetime 형식이 아니라면 변환
questionset['created_at'] = pd.to_datetime(questionset['created_at'])

# '일(day)' 컬럼 추출
questionset['day'] = questionset['created_at'].dt.day

# 1~30일만 필터링 (31일 제외)
day_counts = questionset[questionset['day'] <= 30]['day'].value_counts().sort_index()

# 막대그래프 그리기
plt.figure(figsize=(10, 5))
day_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('1일부터 30일까지 날짜별 Questionset 생성 수',fontproperties=fontprop)
plt.xlabel('일(day of month)',fontproperties=fontprop)
plt.ylabel('생성된 개수',fontproperties=fontprop)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# question_count 기본값 0
questionset['question_count'] = 0

# F인 경우에만 user_id별로 10씩 증가하는 count 부여
mask = questionset['status'] == 'F'
questionset.loc[mask, 'question_count'] = (
    questionset[mask]
    .groupby('user_id')
    .cumcount()
    .add(1)
    .mul(10)
)

#  user_id별로 question_count 합산
user_summary = questionset.groupby('user_id', as_index=False)['question_count'].sum()
user_summary.rename(columns={'question_count': 'total_question_count'}, inplace=True)

print(user_summary)
# Out:
#       user_id  total_question_count
# 0     1001157                  5950
# 1     1001222                   910
# 2     1001373                  2760
# 3     1001561                   210
# 4     1001607                  4960
# ...       ...                   ...
# 4967   998276                  1710
# 4968   998599                  9900
# 4969   998903                  5950
# 4970   999407                  5280
# 4971   999507                 44650
#
# [4972 rows x 2 columns]

# %%
paymenthistory_id = set(paymenthistory['user_id'].unique())
user_summary_id = set(user_summary['user_id'].unique())

# 겹치는 ID 확인
common_ids = paymenthistory_id.intersection(user_summary_id)

# 결과 출력
print(f"겹치는 ID 수: {len(common_ids)}")
paymenthistory.user_id.nunique(), user_summary.user_id.nunique(), user.id.nunique()
# Out:
# 겹치는 ID 수: 410
# (59192, 4972, 677085)

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)

print(user_summary['total_question_count'].describe())
# 50% 300번의 질문 세트를 경험한 유저들. 꽤 많은 질문 세트를 소화했으면 혹시 질문이 중복되어 나오진 않을까? 같은 질문이 나오는 경험을 하면 흥미가 떨어질 가능성이 있을 것 같다.
# Out:
# count     4,972
# mean      8,623
# std      19,566
# min           0
# 25%         780
# 50%       3,000
# 75%       8,610
# max     682,650
# Name: total_question_count, dtype: float64

# %%
# 사용자별 총 포인트 변화량 (절대값으로 변화량 측정 및 합산)
point_summary = (
    pointhistory
    .assign(abs_point=lambda df: df['delta_point'].abs())
    .groupby('user_id', as_index=False)['abs_point']
    .sum()
    .rename(columns={'abs_point': 'total_point_change'})
)

# 참여도 지표랑 포인트 활동량 병합
summary_df = pd.merge(user_summary, point_summary, on='user_id', how='inner')

# 참여도 기준으로 3개 그룹으로 나누기
summary_df['activity_group'] = pd.qcut(
    summary_df['total_question_count'],
    q=3,
    labels=['Low', 'Medium', 'High']
)
# 그룹별 평균 포인트 변화량
group_avg = (
    summary_df
    .groupby('activity_group', as_index=False)['total_point_change']
    .mean()
    .rename(columns={'total_point_change': 'avg_total_point_change'})
)

print(group_avg)
# Out:
#   activity_group  avg_total_point_change
# 0            Low                   3,791
# 1         Medium                   8,040
# 2           High                  15,391
# /tmp/ipykernel_488632/2958360940.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('activity_group', as_index=False)['total_point_change']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.barplot(data=group_avg, x='activity_group', y='avg_total_point_change', palette='coolwarm')

plt.title('참여도 그룹별 평균 포인트 변화량 (절대값 기준)',fontproperties=fontprop)
plt.xlabel('참여도 그룹',fontproperties=fontprop)
plt.ylabel('평균 포인트 변화량',fontproperties=fontprop)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_488632/3745891521.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=group_avg, x='activity_group', y='avg_total_point_change', palette='coolwarm')

# %%
import pandas as pd

point_summary = (
    pointhistory
    .assign(abs_point=lambda df: df['delta_point'].abs())
    .groupby('user_id', as_index=False)['abs_point']
    .sum()
    .rename(columns={'abs_point': 'total_point_change'})
)



# 참여도 데이터와 병합
ccor_df = pd.merge(user_summary, point_summary, on='user_id', how='inner')

# 상관계수 확인 (Pearson)
correlation = ccor_df[['total_question_count', 'total_point_change']].corr().iloc[0,1]
print(f" Pearson 상관계수: {correlation:.4f}")
# Out:
#  Pearson 상관계수: 0.6005

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.set(style='whitegrid')

# 산점도 + 회귀선 시각화
sns.regplot(
    data=ccor_df,
    x='total_question_count',
    y='total_point_change',
    scatter_kws={'alpha': 0.6},
    line_kws={'color': 'red'},
)

plt.title('💡 질문 참여도 vs 포인트 변화 상관 분석', fontsize=14, fontweight='bold',fontproperties=fontprop)
plt.xlabel('총 질문 참여도 (total_question_count)',fontproperties=fontprop)
plt.ylabel('총 포인트 변화량 (total_point_change)',fontproperties=fontprop)
plt.tight_layout()
# 이를 통해 참여도에 따라 포인트 획득과 소비가 활발해진다는 상관관계를 확인할 수 있다.(인과관계는 x, 추후 a/b 테스트를 제안하여 인과관계를 증명하는 것을 추천할 수 있다.)
# Out:
# /tmp/ipykernel_488632/1428564688.py:19: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) NanumGothic.
#   plt.tight_layout()
# /home/hq_key/codeit-project-docker/hackle/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) NanumGothic.
#   func(*args, **kwargs)
# /home/hq_key/codeit-project-docker/hackle/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128161 (\N{ELECTRIC LIGHT BULB}) missing from font(s) NanumGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### [3] OS 버전 변화와 `session_id` 연관성 검토 (민정,연우)
#
# - **질문**: 사용자의 OS 버전(`os_version`)이 바뀌면 `session_id`도 바뀌는가?
# - **분석 방향**:
#     - 동일 유저 내 시간 순으로 `os_version`과 `session_id` 변화 패턴 분석.
#     - 특정 버전 변경이 `session_id` 변경과 직접적인 관련이 있는지 여부 확인.

# %%
import pandas as pd

# 데이터 불러오기
df = hackle_properties.copy()

# osversion 변경 감지를 위해 정렬
df = df.sort_values(by=['user_id', 'id'])  # 시간순 정렬 (id 기준)

# 사용자별 osversion 이전 값과 비교
df['osversion_prev'] = df.groupby('user_id')['osversion'].shift(1)
df['session_id_prev'] = df.groupby('user_id')['session_id'].shift(1)

# osversion이 변경된 행만 필터링
os_changed = df[df['osversion'] != df['osversion_prev']].copy()

# 각 행에 대해 session_id가 변경되었는지 여부 계산
os_changed['session_changed'] = os_changed['session_id'] != os_changed['session_id_prev']

# 결과 확인
summary = os_changed['session_changed'].value_counts()

# 어떤 user_id에서 변경이 있었는지 보기
changed_users = os_changed[['user_id', 'osversion_prev', 'osversion', 'session_id_prev', 'session_id', 'session_changed']]
# 해클 프로퍼티스랑 이벤트 엮고 session_id 날리고 분석

# %%
summary
# Out:
# session_changed
# True     392068
# False     17652
# Name: count, dtype: int64

# %%
import pandas as pd

df = hackle_properties.copy()

# 시간 순 정렬
df = df.sort_values(by=['user_id', 'id'])  # 또는 timestamp가 있다면 그걸 기준으로

# 이전 osversion과 비교
df['osversion_prev'] = df.groupby('user_id')['osversion'].shift(1)

# osversion이 바뀐 행만 필터링
df['osversion_changed'] = df['osversion'] != df['osversion_prev']

# osversion 변경이 있었던 user_id 집합 추출
user_with_os_change = df[df['osversion_changed']]['user_id'].unique()

# 전체 사용자 수
total_users = df['user_id'].nunique()

# 변경된 사용자 수
changed_users = len(user_with_os_change)

# 비율 계산
change_ratio = changed_users / total_users * 100

print(f"전체 사용자 수: {total_users}")
print(f"osversion이 변경된 사용자 수: {changed_users}")
print(f"변경된 사용자 비율: {change_ratio:.2f}%")
# Out:
# 전체 사용자 수: 327381
# osversion이 변경된 사용자 수: 327381
# 변경된 사용자 비율: 100.00%

# %% [markdown]
# # “질문을 많이 받은 유저일수록, 초성 열람을 위해 실제로 하트를 결제했을 가능성이 높다.”
# ### 질문을 많이 받은 유저일수록 하트 많이 사용했을 것이다 가설 검증, 아니면 질문 많이 받았는데 하트 많이 안삿어 그럼 왜일까 포인트 수급 구조가 하트 구매를 막고 있는가.

# %% [markdown]
# ### 우선 질문에 참여한 유저들에 대한 분석 진행

# %%
questionset_id = set(questionset['user_id'].unique())
paymenthistory_id = set(paymenthistory['user_id'].unique())

# 겹치는 ID 확인
common_ids = paymenthistory_id.intersection(questionset_id)

# 결과 출력
print(f"겹치는 ID 수: {len(common_ids)}")
# 질문에 참여한 유저 중에서도 결제 유저는 410명
# Out:
# 겹치는 ID 수: 410

# %%
pointhistory['created_at'].sort_values()
# 결제 기록은 4월 28일부터 남아있음
# Out:
# 0         2023-04-28 12:27:49
# 1         2023-04-28 12:28:02
# 2         2023-04-28 12:28:09
# 3         2023-04-28 12:28:16
# 4         2023-04-28 12:28:26
#                   ...
# 2338913   2024-05-08 01:35:02
# 2338914   2024-05-08 01:36:00
# 2338915   2024-05-08 01:36:00
# 2338916   2024-05-08 01:36:18
# 2338917   2024-05-08 01:36:18
# Name: created_at, Length: 2338918, dtype: datetime64[ns]

# %%
# 결제 유저 ID만 추출
paid_user_ids = set(paymenthistory['user_id'].unique())

# user_summary에 결제 여부 컬럼 추가
user_summary['is_paid_user'] = user_summary['user_id'].apply(
    lambda uid: '1' if uid in paid_user_ids else '0'
)
# 그룹별 평균 참여도
group_stats = (
    user_summary
    .groupby('is_paid_user', as_index=False)['total_question_count']
    .mean()
    .rename(columns={'total_question_count': 'avg_question_count'})
)

print(group_stats)
# Out:
#   is_paid_user  avg_question_count
# 0            0               7,999
# 1            1              15,567

# %%
group_stats
# Out:
#   is_paid_user  avg_question_count
# 0            0               7,999
# 1            1              15,567

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 참여도 상중하 그룹 분류 (qcut 사용)
user_summary['activity_group'] = pd.qcut(
    user_summary['total_question_count'],
    q=3,
    labels=['Low', 'Medium', 'High']
)

# 결제 유저 구분
paid_user_ids = set(paymenthistory['user_id'].unique())
user_summary['is_paid_user'] = user_summary['user_id'].apply(
    lambda x: '1' if x in paid_user_ids else '0'
)

# 그룹별 유저 수 확인
group_counts = (
    user_summary
    .groupby(['activity_group', 'is_paid_user'])
    .size()
    .reset_index(name='user_count')
)

print(group_counts)
# Out:
#   activity_group is_paid_user  user_count
# 0            Low            0        1651
# 1            Low            1          65
# 2         Medium            0        1473
# 3         Medium            1         129
# 4           High            0        1438
# 5           High            1         216
# /tmp/ipykernel_488632/1324441698.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['activity_group', 'is_paid_user'])

# %% [markdown]
# | 참여도 그룹 | 총 유저 수 | 결제 비율 (%) |
# | ------ | ------ | --------- |
# | Low    | 1,716  | 3.8%      |
# | Medium | 1,602  | 8.1%      |
# | High   | 1,654  | 13.1%     |

# %%
import matplotlib.pyplot as plt

# 데이터 정의
group_labels = ['Low', 'Medium', 'High']
user_counts = [1716, 1602, 1654]
paid_rates = [3.8, 8.1, 13.1]

# 시각화
plt.figure(figsize=(12, 6))
bars = plt.bar(group_labels, paid_rates, color='#14213d')

# 강조: 결제율이 가장 높은 그룹(High)
max_rate = max(paid_rates)
for i, rate in enumerate(paid_rates):
    if rate == max_rate:
        bars[i].set_color('#fca311')  # 강조 색상

# 제목 및 라벨
plt.title("참여도 그룹별 결제율 (%)", fontsize=18, fontproperties=fontprop)
plt.xlabel("참여도 그룹", fontsize=17, fontproperties=fontprop)
plt.ylabel("결제율 (%)", fontsize=17, fontproperties=fontprop)

# 값 표시
for i, v in enumerate(paid_rates):
    plt.text(i, v + 0.5, f"{v:.1f}%", ha='center', fontsize=15, color='#2b2d42')

# 눈금 설정
plt.xticks(fontsize=15)
plt.yticks(fontsize=12)

# 스타일
plt.grid(axis='y', linestyle='--', color='#e5e5e5', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
user_summary
# Out:
#       user_id  total_question_count is_paid_user activity_group
# 0     1001157                  5950            0         Medium
# 1     1001222                   910            0            Low
# 2     1001373                  2760            0         Medium
# 3     1001561                   210            0            Low
# 4     1001607                  4960            0         Medium
# ...       ...                   ...          ...            ...
# 4967   998276                  1710            0         Medium
# 4968   998599                  9900            0           High
# 4969   998903                  5950            0         Medium
# 4970   999407                  5280            0         Medium
# 4971   999507                 44650            0           High
#
# [4972 rows x 4 columns]

# %%
# 1) paymenthistory에서 heart 개수 추출
paymenthistory['heart_amount'] = (
    paymenthistory['productId']     
    .str.split('.')             
    .str[-1]                         
    .astype(int)                 
)

# 2) user_id별 총 구매 하트 합계 → total_spent
user_total_heart = (
    paymenthistory
    .groupby('user_id', as_index=False)['heart_amount']
    .sum()
    .rename(columns={'heart_amount': 'total_spent'})
)

# 3) 기존 user_summary와 머지
user_summary = user_summary.merge(
    user_total_heart,
    on='user_id',
    how='left'
)

# 4) 결제 내역이 없는 유저는 0으로 채워주기
user_summary['total_spent'] = (
    user_summary['total_spent']
    .fillna(0)
    .astype(int)
)

# %%
# 참여도 그룹별 총합, 평균 계산
group_heart_stats = (
    user_summary
    .groupby('activity_group')['total_spent']
    .agg(['sum', 'mean'])
    .reset_index()
    .rename(columns={'sum': '총 구매 하트 수', 'mean': '평균 구매 하트 수'})
)

print(group_heart_stats)
# Out:
#   activity_group  총 구매 하트 수  평균 구매 하트 수
# 0            Low      58551          34
# 1         Medium     132794          83
# 2           High     288655         175
# /tmp/ipykernel_488632/1543851872.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('activity_group')['total_spent']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 참여도 그룹 나누기
user_summary['activity_group'] = pd.qcut(
    user_summary['total_question_count'],
    q=3,
    labels=['Low', 'Medium', 'High']
)

# 하트 소모 데이터 추출 (delta_point < 0)
consumed_df = pointhistory[pointhistory['delta_point'] < 0].copy()
consumed_df['point_consumed'] = consumed_df['delta_point'].abs()

# 유저별 하트 총 소모량 집계
consumed_summary = (
    consumed_df.groupby('user_id', as_index=False)['point_consumed']
    .sum()
)

# 참여도 요약 데이터와 병합
merged = pd.merge(user_summary, consumed_summary, on='user_id', how='inner')

# 참여도 그룹별 하트 소모량 평균 비교
group_heart_summary = (
    merged.groupby('activity_group', as_index=False)['point_consumed']
    .mean()
    .rename(columns={'point_consumed': 'avg_heart_consumed'})
)

print(group_heart_summary)
# Out:
#   activity_group  avg_heart_consumed
# 0            Low               2,117
# 1         Medium               3,841
# 2           High               7,380
# /tmp/ipykernel_488632/2945346169.py:27: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   merged.groupby('activity_group', as_index=False)['point_consumed']

# %% [markdown]
# ### 질문을 받은 유저들에 대한 분석

# %%
questionrecord_id = set(userquestionrecord['chosen_user_id'].unique())
paymenthistory_id = set(paymenthistory['user_id'].unique())

# 겹치는 ID 확인
common_ids = paymenthistory_id.intersection(questionrecord_id)

# 결과 출력
print(f"겹치는 ID 수: {len(common_ids)}")
# 질문을 받은 유저 중 결제 유저는 410명
# Out:
# 겹치는 ID 수: 1213

# %%
userquestionrecord #전체 중 초성 열림의 비율을 확인해보는 것도 좋을 것 같음 결제 비율과 비교해도 좋을 듯
# Out:
#                 id status          created_at chosen_user_id  question_id  \
# 0           771777      C 2023-04-28 12:27:49         849469          252
# 1           771800      C 2023-04-28 12:28:02         849446          244
# 2           771812      C 2023-04-28 12:28:09         849454          183
# 3           771828      C 2023-04-28 12:28:16         847375          101
# 4           771851      C 2023-04-28 12:28:26         849477          209
# ...            ...    ...                 ...            ...          ...
# 1217553  161666166      C 2024-05-07 11:29:07         945560         2614
# 1217554  161666461      C 2024-05-08 01:34:56         850774         1679
# 1217555  161666462      C 2024-05-08 01:35:02         855509         2605
# 1217556  161666463      C 2024-05-08 01:36:00         855526         3801
# 1217557  161666464      C 2024-05-08 01:36:18         874566         3117
#
#          user_id  question_piece_id has_read answer_status  \
# ...

# %%
# chosen_user_id 기준으로 등장 횟수 집계
user_question_count = (
    userquestionrecord['chosen_user_id']
    .value_counts()
    .reset_index()
    .rename(columns={'index': 'chosen_user_id', 'chosen_user_id': 'user_id'})
)

# %%
user_question_count
# Out:
#        user_id  count
# 0       913265   1239
# 1      1206668   1054
# 2      1402487   1049
# 3      1122686   1042
# 4       994573    997
# ...        ...    ...
# 15421   901315      1
# 15422  1543251      1
# 15423  1267227      1
# 15424  1237618      1
# 15425   854411      1
#
# [15426 rows x 2 columns]

# %%
# 결제 유저 ID만 추출
paid_user_ids = set(paymenthistory['user_id'].unique())

# user_question_count에 결제 여부 컬럼 추가
user_question_count['is_paid_user'] = user_question_count['user_id'].apply(
    lambda uid: '결제 유저' if uid in paid_user_ids else '비결제 유저'
)
# 그룹별 평균 참여도
received_group_stats = (
    user_question_count
    .groupby('is_paid_user', as_index=False)['count']
    .mean()
    .rename(columns={'count': 'avg_count'})
)

print(received_group_stats)
# Out:
#   is_paid_user  avg_count
# 0        결제 유저         94
# 1       비결제 유저         78

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 참여도 상중하 그룹 분류 (qcut 사용)
user_question_count['question_group'] = pd.qcut(
    user_question_count['count'],
    q=3,
    labels=['Low', 'Medium', 'High']
)

# 결제 유저 구분
paid_user_ids = set(paymenthistory['user_id'].unique())
user_question_count['is_paid_user'] = user_question_count['user_id'].apply(
    lambda x: '결제 유저' if x in paid_user_ids else '비결제 유저'
)

# 그룹별 유저 수 확인
received_group_counts = (
    user_question_count
    .groupby(['question_group', 'is_paid_user'])
    .size()
    .reset_index(name='user_count')
)

print(received_group_counts)
# Out:
#   question_group is_paid_user  user_count
# 0            Low        결제 유저         444
# 1            Low       비결제 유저        5096
# 2         Medium        결제 유저         334
# 3         Medium       비결제 유저        4436
# 4           High        결제 유저         435
# 5           High       비결제 유저        4681
# /tmp/ipykernel_488632/1210399635.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['question_group', 'is_paid_user'])

# %% [markdown]
# | 질문 그룹  | 결제 유저 수 | 비결제 유저 수 | 전체 유저 수 | 결제 유저 비율 (%) |
# | ------ | ------- | -------- | ------- | ------------ |
# | Low    | 444      | 5,096    | 5,540   | 8.01%        |
# | Medium | 334     | 4,436    | 4,770   | 7.00%        |
# | High   | 435     | 4,681    | 5,116   | 8.50%       |

# %% [markdown]
# 평균적으로 결제 유저는 94, 비 결제 유저는 78개의 질문을 받았는데 단 한 번도 결제를 하지 않은 유저가 90% 이상이나 된다. 왜일까?
# 두가지 이유를 생각해볼 수 있다.
# 첫 번째, 초성이 궁금할 정도의 질문이 없었다. 누가 나에게 투표했는 지 궁금해질 정도로 질문이 메리트 있지 않았던 것.
# 두 번째, 결제를 하지 않아도 초성을 오픈할 수 있었다. 우리는 앞선 분석으로 질문에 참여하면 포인트를 주는 것을 확인하였다. 이를 통해 초성을 오픈하고 싶을 때 질문 세트를 여러개 진행해버리면      결제가 필요하지 않을 정도로 쌓이는 것 아닐까?

# %%
# 1. delta_point가 양수인 유저 포인트 획득량 합계
point_earned = (
    pointhistory[pointhistory['delta_point'] > 0]
    .groupby('user_id', as_index=False)['delta_point']
    .sum()
    .rename(columns={'delta_point': 'total_point_earned'})
)

# 2. 질문 받은 횟수와 포인트 획득량 병합
user_question_with_point = pd.merge(
    user_question_count,
    point_earned,
    on='user_id',
    how='left'
)

# 3. 포인트 기록이 없는 경우 0으로 채우기
user_question_with_point['total_point_earned'] = user_question_with_point['total_point_earned'].fillna(0)

# 확인
print(user_question_with_point.head())
# Out:
#    user_id  count is_paid_user question_group  total_point_earned
# 0   913265   1239       비결제 유저           High              14,315
# 1  1206668   1054       비결제 유저           High              14,793
# 2  1402487   1049       비결제 유저           High              13,492
# 3  1122686   1042       비결제 유저           High              11,471
# 4   994573    997       비결제 유저           High              13,419

# %%
user_question_with_point['total_point_earned'].describe()
# Out:
# count   15,426
# mean     1,499
# std      2,907
# min          0
# 25%          0
# 50%          0
# 75%      2,004
# max     38,998
# Name: total_point_earned, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.histplot(user_question_with_point['total_point_earned'], bins=50, kde=True, color='skyblue')

plt.title('유저별 질문을 통한 포인트 획득 분포',fontproperties=fontprop)
plt.xlabel('총 획득 포인트',fontproperties=fontprop)
plt.ylabel('유저 수',fontproperties=fontprop)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x=user_question_with_point['total_point_earned'], color='orange')

plt.title('포인트 획득량 박스플롯',fontproperties=fontprop)
plt.xlabel('총 획득 포인트',fontproperties=fontprop)
plt.tight_layout()
plt.show()

# %%
# opened_times 유저별 합산
opened_summary = (
    userquestionrecord
    .groupby('user_id', as_index=False)['opened_times']
    .sum()
    .rename(columns={'opened_times': 'total_opened_times'})
)

# 기존 테이블과 병합
user_question_with_point = pd.merge(
    user_question_with_point,
    opened_summary,
    on='user_id',
    how='left'  # 존재하지 않는 유저는 NaN 처리
)

# NaN → 0 으로 채우기
user_question_with_point['total_opened_times'] = user_question_with_point['total_opened_times'].fillna(0).astype(int)

# %%
# 1) paymenthistory에서 heart 개수 추출
paymenthistory['heart_amount'] = (
    paymenthistory['productId']       
    .str.split('.')                
    .str[-1]                        
    .astype(int)                       
)

# 2) user_id별 총 구매 하트 합계 → total_spent
user_total_heart = (
    paymenthistory
    .groupby('user_id', as_index=False)['heart_amount']
    .sum()
    .rename(columns={'heart_amount': 'total_spent'})
)

# 3) 기존 user_question_count와 머지
user_question_count = user_question_count.merge(
    user_total_heart,
    on='user_id',
    how='left'
)

# 4) 결제 내역이 없는 유저는 0으로 채워주기
user_question_count['total_spent'] = (
    user_question_count['total_spent']
    .fillna(0)
    .astype(int)
)

# %%
# 참여도 그룹 나누기
user_question_count['question_group'] = pd.qcut(
    user_question_count['count'],
    q=3,
    labels=['Low', 'Medium', 'High']
)

# 하트 소모 데이터 추출 (delta_point < 0)
consumed_df = pointhistory[pointhistory['delta_point'] < 0].copy()
consumed_df['point_consumed'] = consumed_df['delta_point'].abs()

# 유저별 하트 총 소모량 집계
consumed_summary2 = (
    consumed_df.groupby('user_id', as_index=False)['point_consumed']
    .sum()
)

# 참여도 요약 데이터와 병합
merged2 = pd.merge(user_question_count, consumed_summary2, on='user_id', how='inner')

# 참여도 그룹별 하트 소모량 평균 비교
group_heart_summary2 = (
    merged2.groupby('question_group', as_index=False)['point_consumed']
    .mean()
    .rename(columns={'point_consumed': 'avg_heart_consumed'})
)

print(group_heart_summary2)
# Out:
#   question_group  avg_heart_consumed
# 0            Low                 708
# 1         Medium               1,685
# 2           High               4,915
# /tmp/ipykernel_488632/3897587284.py:23: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   merged2.groupby('question_group', as_index=False)['point_consumed']

# %%
# 참여도 그룹별 총합, 평균 계산
group_heart_stats2 = (
    user_question_count
    .groupby('question_group')['total_spent']
    .agg(['sum', 'mean'])
    .reset_index()
    .rename(columns={'sum': '총 구매 하트 수', 'mean': '평균 구매 하트 수'})
)

print(group_heart_stats2)
# Out:
#   question_group  총 구매 하트 수  평균 구매 하트 수
# 0            Low     617972         112
# 1         Medium     383302          80
# 2           High     525202         103
# /tmp/ipykernel_488632/248600301.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('question_group')['total_spent']

# %%
group_heart_stats
# Out:
#   activity_group  총 구매 하트 수  평균 구매 하트 수
# 0            Low      58551          34
# 1         Medium     132794          83
# 2           High     288655         175

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 막대그래프: 평균 구매 하트 수
plt.figure(figsize=(8, 5))
sns.barplot(
    data=group_heart_stats,
    x='activity_group',
    y='평균 구매 하트 수',
    palette='viridis'
)
plt.title('참여도 그룹별 평균 하트 구매 수',fontproperties=fontprop)
plt.ylabel('평균 구매 하트 수',fontproperties=fontprop)
plt.xlabel('참여도 그룹',fontproperties=fontprop)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_488632/3647220539.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# 직원인 유저만 필터링
staff_users = user[user['is_staff'] == True]
staff_users
# Out:
#              id  is_superuser  is_staff gender  point  \
# 0        831956             1         1   None    600
# 673997  1580627             0         1      M    300
# 674052  1580689             0         1   None      0
#
#                                            friend_id_list  is_push_on  \
# 0       [1292473, 913158, 1488461, 1064695, 1043565, 1...           0
# 673997                                                 []           1
# 674052                                                 []           0
#
#                        created_at block_user_id_list hide_user_id_list  \
# 0      2023-03-29 03:44:14.047130                 []                []
# 673997 2023-09-23 06:12:28.455787                 []                []
# 674052 2023-09-24 17:39:12.897884                 []                []
#
#        ban_status  report_count  alarm_count  pending_chat  pending_votes  \
# 0               N             0            0             0              0
# ...

# %%
user_summary['is_paid_user'] = user_summary['is_paid_user'].astype(int)

# %%
# 스태프 ID 리스트
staff_ids = [831956, 1580627, 1580689]

# user_summary에 존재하는 스태프 ID
summary_matches = user_summary[user_summary['user_id'].isin(staff_ids)]
print("✅ user_summary에서 발견된 스태프 ID:")
print(summary_matches['user_id'].unique())

# user_question_with_point에 존재하는 스태프 ID
question_matches = user_question_with_point[user_question_with_point['user_id'].isin(staff_ids)]
print("\n✅ user_question_with_point에서 발견된 스태프 ID:")
print(question_matches['user_id'].unique())
# Out:
# ✅ user_summary에서 발견된 스태프 ID:
# []
#
# ✅ user_question_with_point에서 발견된 스태프 ID:
# []

# %% [markdown]
# # 가설 검정

# %% [markdown]
# 가설 설정
# 귀무가설 (H₀): 질문 참여도 그룹과 결제 여부는 서로 독립이다 (즉, 관련 없음)
#
# 대립가설 (H₁): 질문 참여도 그룹과 결제 여부는 독립이 아니다 (즉, 관련 있음)
#
# 이를 바탕으로 카이제곱 검정 진행

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# 교차표 생성
contingency = pd.crosstab(user_summary['activity_group'], user_summary['is_paid_user'])

# 카이제곱 독립성 검정
chi2, p, dof, expected = chi2_contingency(contingency)

print("▶ 교차표:")
print(contingency, '\n')
print(f"▶ 카이제곱 통계량: {chi2:.4f}")
print(f"▶ 자유도: {dof}")
print(f"▶ p-value: {p:.6f}")
# Out:
# ▶ 교차표:
# is_paid_user       0    1
# activity_group
# Low             1651   65
# Medium          1473  129
# High            1438  216
#
# ▶ 카이제곱 통계량: 95.8001
# ▶ 자유도: 2
# ▶ p-value: 0.000000

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# 교차표 생성
contingency2 = pd.crosstab(user_question_count['question_group'], user_question_count['is_paid_user'])

# 카이제곱 독립성 검정
chi2, p, dof, expected = chi2_contingency(contingency2)

print("▶ 교차표:")
print(contingency2, '\n')
print(f"▶ 카이제곱 통계량: {chi2:.4f}")
print(f"▶ 자유도: {dof}")
print(f"▶ p-value: {p:.6f}")
# Out:
# ▶ 교차표:
# is_paid_user    결제 유저  비결제 유저
# question_group
# Low               444    5096
# Medium            334    4436
# High              435    4681
#
# ▶ 카이제곱 통계량: 7.9450
# ▶ 자유도: 2
# ▶ p-value: 0.018827

# %% [markdown]
# # 시각화 자료 생성

# %%
# 결제 여부 별 평균 질문 수
import matplotlib.pyplot as plt
import seaborn as sns

# 시각화 설정
plt.figure(figsize=(12, 6))
sns.barplot(
    data=group_stats,
    x='is_paid_user',
    y='avg_question_count',
    palette=['#14213d', '#fca311']  # 0=미결제자, 1=결제자
)

# 텍스트 설정
plt.title('결제 여부에 따른 평균 질문 수', fontsize=18,fontproperties=fontprop)
plt.xlabel('결제 유저 여부 (0=미결제, 1=결제)', fontsize=17,fontproperties=fontprop)
plt.ylabel('평균 질문 수', fontsize=17,fontproperties=fontprop)
plt.xticks(fontsize=15)
plt.yticks(fontsize=12)

# 수치 라벨 추가
for index, row in group_stats.iterrows():
    plt.text(index, row['avg_question_count'] + 0.5, f"{row['avg_question_count']:.1f}",
             ha='center', fontsize=12, color='#2b2d42')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_488632/3524277008.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=group_heart_summary, x='activity_group', y='avg_heart_consumed', palette=[ '#14213d', "#e5e5e5", '#fca311' ])

plt.title('참여도 그룹별 평균 하트(포인트) 소모량', fontsize=13,fontproperties=fontprop)
plt.xlabel('참여도 그룹',fontproperties=fontprop)
plt.ylabel('평균 하트 소모량',fontproperties=fontprop)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_488632/1794472004.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=group_heart_summary, x='activity_group', y='avg_heart_consumed', palette=[ '#14213d', "#e5e5e5", '#fca311' ])

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    data=group_counts,
    x='activity_group',
    y='user_count',
    hue='is_paid_user',
    palette=['#14213d', '#fca311']
)

plt.title('참여도 및 결제 여부에 따른 유저 수 분포', fontsize=18, fontproperties=fontprop)
plt.xlabel('참여도 그룹', fontsize=17, fontproperties=fontprop)
plt.ylabel('유저 수', fontsize=17, fontproperties=fontprop)
plt.xticks(fontsize=15, fontproperties=fontprop)
plt.yticks(fontsize=12, fontproperties=fontprop)
plt.legend(title='is_paid', title_fontsize=13, fontsize=12, prop=fontprop)


# 수치 표시 (막대의 정확한 x좌표 위치 계산)
for container in plt.gca().containers:
    for bar in container:
        height = bar.get_height()
        xpos = bar.get_x() + bar.get_width() / 2
        plt.text(
            xpos, height + 0.5,
            f"{int(height)}",
            ha='center', fontsize=11, fontproperties=fontprop
        )

plt.tight_layout()
plt.show()

# %%
# 시각화: 참여도 그룹별 평균 하트 소모량
plt.figure(figsize=(12, 6))
sns.barplot(
    data=group_heart_summary,
    x='activity_group',
    y='avg_heart_consumed',
    palette=[ '#14213d', "#355c26", '#fca311' ]
)

plt.title('참여도 그룹별 평균 하트 소모량', fontsize=18, fontproperties=fontprop)
plt.xlabel('참여도 그룹', fontsize=17, fontproperties=fontprop)
plt.ylabel('평균 하트 소모량', fontsize=17, fontproperties=fontprop)
plt.xticks(fontsize=15, fontproperties=fontprop)
plt.yticks(fontsize=12, fontproperties=fontprop)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_488632/2015886366.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# 시각화: 참여도 그룹별 평균 하트 소모량
plt.figure(figsize=(12, 6))
sns.barplot(
    data=group_heart_summary2,
    x='question_group',
    y='avg_heart_consumed',
    palette=[ '#14213d', "#e5e5e5", '#fca311' ]
)

plt.title('참여도 그룹별 평균 하트 소모량', fontsize=18, fontproperties=fontprop)
plt.xlabel('참여도 그룹', fontsize=17, fontproperties=fontprop)
plt.ylabel('평균 하트 소모량', fontsize=17, fontproperties=fontprop)
plt.xticks(fontsize=15, fontproperties=fontprop)
plt.yticks(fontsize=12, fontproperties=fontprop)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_488632/1247482463.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 시각화 시작
fig, ax1 = plt.subplots(figsize=(12, 6))

# 첫 번째 y축: 총 구매 하트 수 (왼쪽)
barplot = sns.barplot(
    data=group_heart_stats,
    x='activity_group',
    y='총 구매 하트 수',
    ax=ax1,
    palette=[ '#14213d', "#e5e5e5", '#fca311' ]
)
ax1.set_ylabel('총 구매 하트 수', fontsize=17, color='#14213d', fontproperties=fontprop)
ax1.tick_params(axis='y', labelsize=12, labelcolor='#14213d')
ax1.set_xlabel('질문 참여도 그룹', fontsize=17, fontproperties=fontprop)
ax1.tick_params(axis='x', labelsize=15)
ax1.set_title('질문 참여도 그룹별 하트 구매 현황', fontsize=18, fontproperties=fontprop)

# 막대 위에 총 하트 수 숫자 표기
for i, bar in enumerate(barplot.patches):
    height = bar.get_height()
    ax1.text(
        bar.get_x() + bar.get_width() / 2,
        height + max(group_heart_stats['총 구매 하트 수']) * 0.01,
        f'{int(height):,}',
        ha='center',
        va='bottom',
        fontsize=12,
        fontproperties=fontprop,
        color='#14213d'
    )

plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_488632/4249240086.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 시각화 시작
fig, ax1 = plt.subplots(figsize=(12, 6))

# 첫 번째 y축: 총 구매 하트 수 (왼쪽)
barplot = sns.barplot(
    data=group_heart_stats2,
    x='question_group',
    y='총 구매 하트 수',
    ax=ax1,
    palette=[ '#14213d', "#e5e5e5", '#fca311' ]
)
ax1.set_ylabel('총 구매 하트 수', fontsize=17, color='#14213d', fontproperties=fontprop)
ax1.tick_params(axis='y', labelsize=12, labelcolor='#14213d')
ax1.set_xlabel('참여도 그룹', fontsize=17, fontproperties=fontprop)
ax1.tick_params(axis='x', labelsize=15)
ax1.set_title('참여도 그룹별 하트 구매 현황', fontsize=18, fontproperties=fontprop)

# 막대 위에 총 하트 수 숫자 표기
for i, bar in enumerate(barplot.patches):
    height = bar.get_height()
    ax1.text(
        bar.get_x() + bar.get_width() / 2,
        height + max(group_heart_stats['총 구매 하트 수']) * 0.01,
        f'{int(height):,}',
        ha='center',
        va='bottom',
        fontsize=12,
        fontproperties=fontprop,
        color='#14213d'
    )

plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_488632/1797420042.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(

# %%
pointhistory
# Out:
#                 id  delta_point          created_at user_id  \
# 0           790629            9 2023-04-28 12:27:49  849436
# 1           790652            9 2023-04-28 12:28:02  849436
# 2           790664            5 2023-04-28 12:28:09  849436
# 3           790680           13 2023-04-28 12:28:16  849436
# 4           790703            5 2023-04-28 12:28:26  849436
# ...            ...          ...                 ...     ...
# 2338913  340672371           14 2024-05-08 01:35:02  855509
# 2338914  340672372           11 2024-05-08 01:36:00  855525
# 2338915  340672373           11 2024-05-08 01:36:00  855526
# 2338916  340672374           12 2024-05-08 01:36:18  855525
# 2338917  340672375           12 2024-05-08 01:36:18  874566
#
#          user_question_record_id
# 0                        771,777
# 1                        771,800
# 2                        771,812
# 3                        771,828
# 4                        771,851
# ...                          ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 예시 데이터 (실제 데이터로 pointhistory.delta_point를 사용하세요)
delta_points = pointhistory['delta_point'].value_counts().sort_index()

# 시각화 설정
plt.figure(figsize=(12, 6))
bars = plt.bar(delta_points.index.astype(str), delta_points.values, color='#14213d')

# 강조: 음수(delta_point < 0)에 색상 강조
for i, val in enumerate(delta_points.index):
    if val < 0:
        bars[i].set_color('#fca311')  # 강조 색상


# 제목 및 라벨
plt.title("고유 포인트 변화량 분포", fontsize=18, fontproperties=fontprop)
plt.xlabel("포인트 변화량 (delta_point)", fontsize=17, fontproperties=fontprop)
plt.ylabel("빈도", fontsize=17, fontproperties=fontprop)

# ✅ 눈금 폰트 크기 및 회전
plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=12)

# 배경 스타일
plt.grid(axis='y', linestyle='--', color='#e5e5e5', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 데이터 정의
group_labels = ['Low', 'Medium', 'High']
paid_rates = [3.8, 8.1, 13.1]
palette = ['#14213d', '#e5e5e5', '#fca311']  # 지정된 색상 팔레트

# 시각화
plt.figure(figsize=(12, 6))
bars = plt.bar(group_labels, paid_rates, color=palette)

# 제목 및 라벨
plt.title("참여도 그룹별 결제율 (%)", fontsize=18, fontproperties=fontprop)
plt.xlabel("참여도 그룹", fontsize=17, fontproperties=fontprop)
plt.ylabel("결제율 (%)", fontsize=17, fontproperties=fontprop)

# 눈금 설정
plt.xticks(fontsize=15)
plt.yticks(fontsize=12)

# 스타일
plt.grid(axis='y', linestyle='--', color='#e5e5e5', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 데이터 정의
group_labels = ['Low', 'Medium', 'High']
paid_rates = [8.01, 7.0, 8.5]
palette = ['#14213d', '#e5e5e5', '#fca311']  # 지정된 색상 팔레트

# 시각화
plt.figure(figsize=(12, 6))
bars = plt.bar(group_labels, paid_rates, color=palette)

# 제목 및 라벨
plt.title("참여도 그룹별 결제율 (%)", fontsize=18, fontproperties=fontprop)
plt.xlabel("참여도 그룹", fontsize=17, fontproperties=fontprop)
plt.ylabel("결제율 (%)", fontsize=17, fontproperties=fontprop)

# 눈금 설정
plt.xticks(fontsize=15)
plt.yticks(fontsize=12)

# 스타일
plt.grid(axis='y', linestyle='--', color='#e5e5e5', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 추가 분석

# %%
user_question_count
# Out:
#        user_id  count is_paid_user question_group  total_spent
# 0       913265   1239       비결제 유저           High            0
# 1      1206668   1054       비결제 유저           High            0
# 2      1402487   1049       비결제 유저           High            0
# 3      1122686   1042       비결제 유저           High            0
# 4       994573    997       비결제 유저           High            0
# ...        ...    ...          ...            ...          ...
# 15421   901315      1       비결제 유저            Low            0
# 15422  1543251      1       비결제 유저            Low            0
# 15423  1267227      1       비결제 유저            Low            0
# 15424  1237618      1       비결제 유저            Low            0
# 15425   854411      1       비결제 유저            Low            0
#
# [15426 rows x 5 columns]

# %%
user_summary
# Out:
#       user_id  total_question_count  is_paid_user activity_group  total_spent
# 0     1001157                  5950             0         Medium            0
# 1     1001222                   910             0            Low            0
# 2     1001373                  2760             0         Medium            0
# 3     1001561                   210             0            Low            0
# 4     1001607                  4960             0         Medium            0
# ...       ...                   ...           ...            ...          ...
# 4967   998276                  1710             0         Medium            0
# 4968   998599                  9900             0           High            0
# 4969   998903                  5950             0         Medium            0
# 4970   999407                  5280             0         Medium            0
# 4971   999507                 44650             0           High            0
#
# [4972 rows x 5 columns]

# %%
# 두 컬럼의 고유값 추출
user_question_count_id = set(user_question_count['user_id'].unique())
questionset_id = set(questionset['user_id'].unique())

# 겹치는 ID 확인
common_ids = user_question_count_id.intersection(questionset_id)

# 결과 출력
print(f"겹치는 ID 수: {len(common_ids)}")
# 동일한 device_id임을 확인.
# Out:
# 겹치는 ID 수: 4929

# %%
merged_df = pd.merge(
    user_question_count,
    user_summary.drop(columns=['is_paid_user','total_spent']),  # 제외하고 싶은 컬럼
    on='user_id',
    how='inner'
)

# %%
merged_df['is_paid'] = (merged_df['is_paid_user'] == '결제 유저').astype(int)
merged_df.user_id.nunique()
# Out:
# 4929

# %%
group_heart_stats3 = (
    merged_df
    .groupby('activity_group')[['total_spent', 'total_question_count']]
    .sum()
    .assign(평균_하트_소모량=lambda df: df['total_spent'] / df['total_question_count'])
    .reset_index()
    .rename(columns={
        'total_spent': '총 하트 구매 수',
        'total_question_count': '총 질문 수'
    })
)

print(group_heart_stats3)
# Out:
#   activity_group  총 하트 구매 수    총 질문 수  평균_하트_소모량
# 0            Low      57574    875100          0
# 1         Medium     132794   5362840          0
# 2           High     288655  36619130          0
# /tmp/ipykernel_488632/1575306762.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('activity_group')[['total_spent', 'total_question_count']]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 시각화 시작
fig, ax1 = plt.subplots(figsize=(12, 6))

# 첫 번째 y축: 총 구매 하트 수 (왼쪽)
barplot = sns.barplot(
    data=group_heart_stats3,
    x='activity_group',
    y='총 하트 구매 수',
    ax=ax1,
    palette=[ '#14213d', "#e5e5e5", '#fca311' ]
)
ax1.set_ylabel('총 구매 하트 수', fontsize=17, color='#14213d', fontproperties=fontprop)
ax1.tick_params(axis='y', labelsize=12, labelcolor='#14213d')
ax1.set_xlabel('질문 참여도 그룹', fontsize=17, fontproperties=fontprop)
ax1.tick_params(axis='x', labelsize=15)
ax1.set_title('피투표율 그룹 중 질문참여자 하트 구매 현황', fontsize=18, fontproperties=fontprop)

# 막대 위에 총 하트 수 숫자 표기
for i, bar in enumerate(barplot.patches):
    height = bar.get_height()
    ax1.text(
        bar.get_x() + bar.get_width() / 2,
        height + max(group_heart_stats3['총 하트 구매 수']) * 0.01,
        f'{int(height):,}',
        ha='center',
        va='bottom',
        fontsize=12,
        fontproperties=fontprop,
        color='#14213d'
    )

plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_488632/2836728405.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(

# %%
unique_users = merged_df[['user_id', 'activity_group', 'is_paid']].drop_duplicates()

group_payment_ratio = (
    unique_users
    .groupby('activity_group', observed=True)
    .agg(
        전체_유저수=('user_id', 'count'),
        결제_유저수=('is_paid', 'sum')
    )
    .reset_index()
)

# 🔥 float로 나눗셈 강제 적용
group_payment_ratio['결제_비율'] = group_payment_ratio['결제_유저수'] / group_payment_ratio['전체_유저수']
group_payment_ratio['결제_비율'] = group_payment_ratio['결제_비율'].round(2)

print(group_payment_ratio)
# Out:
#   activity_group  전체_유저수  결제_유저수  결제_비율
# 0            Low    1675      64      0
# 1         Medium    1601     129      0
# 2           High    1653     216      0

# %% [markdown]
# low - 3.82
# medium - 8.05
# high - 13.06

# %%
import matplotlib.pyplot as plt

# 데이터 정의
group_labels = ['Low', 'Medium', 'High']
paid_rates = [3.82 , 8.05, 13.06]
palette = ['#14213d', '#e5e5e5', '#fca311']  # 지정된 색상 팔레트

# 시각화
plt.figure(figsize=(12, 6))
bars = plt.bar(group_labels, paid_rates, color=palette)

# 제목 및 라벨
plt.title("피투표 그룹 중 질문참여자 결제율 (%)", fontsize=18, fontproperties=fontprop)
plt.xlabel("참여도 그룹", fontsize=17, fontproperties=fontprop)
plt.ylabel("결제율 (%)", fontsize=17, fontproperties=fontprop)

# 눈금 설정
plt.xticks(fontsize=15)
plt.yticks(fontsize=12)

# 스타일
plt.grid(axis='y', linestyle='--', color='#e5e5e5', alpha=0.7)
plt.tight_layout()
plt.show()
